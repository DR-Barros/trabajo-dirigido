# %%
from dsgd import DSClassifierMultiQ
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.metrics import silhouette_score, adjusted_rand_score
from scipy.spatial.distance import cdist
from scipy.stats import pearsonr
from sklearn.datasets import load_iris,load_wine
from sklearn.preprocessing import StandardScaler

# %%
def dunn_index(X, labels):
    unique_labels = np.unique(labels)
    k = len(unique_labels)
    
    # Calcular el diámetro de cada clúster
    diameters = []
    for label in unique_labels:
        cluster_points = X[labels == label]
        if len(cluster_points) > 1:
            diameters.append(np.max(cdist(cluster_points, cluster_points, metric='euclidean')))
        else:
            diameters.append(0)
    
    max_diameter = np.max(diameters)
    
    # Calcular la distancia mínima entre clusters
    min_distances = []
    for i in range(k):
        for j in range(i + 1, k):
            cluster_i_points = X[labels == unique_labels[i]]
            cluster_j_points = X[labels == unique_labels[j]]
            min_distance = np.min(cdist(cluster_i_points, cluster_j_points, metric='euclidean'))
            min_distances.append(min_distance)
    
    min_intercluster_distance = np.min(min_distances)
    
    # Índice de Dunn
    dunn_index_value = min_intercluster_distance / max_diameter
    
    return dunn_index_value

# %% [markdown]
# Experimento

# %%
atom = pd.read_csv('data/Atom_Data.csv')
atom_labels = pd.read_csv('data/Atom_Labels.csv')
chainlink = pd.read_csv('data/Chainlink_Data.csv')
chainlink_labels = pd.read_csv('data/Chainlink_Labels.csv')
engytime = pd.read_csv('data/EngyTime_Data.csv')
engytime_labels = pd.read_csv('data/EngyTime_Labels.csv')
hepta = pd.read_csv('data/Hepta_Data.csv')
hepta_labels = pd.read_csv('data/Hepta_Labels.csv')
tetra = pd.read_csv('data/Tetra_Data.csv')
tetra_labels = pd.read_csv('data/Tetra_Labels.csv')
target = pd.read_csv('data/Target_Data.csv')
target_labels = pd.read_csv('data/Target_Labels.csv')
two_diamonds = pd.read_csv('data/TwoDiamonds_Data.csv')
two_diamonds_labels = pd.read_csv('data/TwoDiamonds_Labels.csv')
wing_nut = pd.read_csv('data/WingNut_Data.csv')
wing_nut_labels = pd.read_csv('data/WingNut_Labels.csv')
# Cargamos los datasets clasico de sklearn
iris = load_iris()
iris_data = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_labels = pd.DataFrame(iris.target, columns=['target'])
wine = load_wine()
wine_data = pd.DataFrame(wine.data, columns=wine.feature_names)
wine_labels = pd.DataFrame(wine.target, columns=['target'])
# Cargamos los datasets de prueba de la tesis
uniform = pd.read_csv('data/uniform_df.csv')
uniform_data = uniform.drop(columns=['labels'])
uniform_labels = pd.DataFrame(uniform['labels'])
rectangle = pd.read_csv('data/rectangle_df.csv')
rectangle_data = rectangle.drop(columns=['labels'])
rectangle_labels = pd.DataFrame(rectangle['labels'])
gaussian = pd.read_csv('data/gaussian_df.csv')
gaussian_data = gaussian.drop(columns=['labels'])
gaussian_labels = pd.DataFrame(gaussian['labels'])
gaussian_mix = pd.read_csv('data/gaussian_mix_df.csv')
gaussian_mix_data = gaussian_mix.drop(columns=['labels'])
gaussian_mix_labels = pd.DataFrame(gaussian_mix['labels'])
datasets = [
    {
        'name': 'Atom',
        'data': atom,
        'labels': atom_labels,
        'n_clusters': atom_labels.nunique().values[0]
    },{
        'name': 'Chainlink',
        'data': chainlink,
        'labels': chainlink_labels,
        'n_clusters': chainlink_labels.nunique().values[0]
    },{
        'name': 'EngyTime',
        'data': engytime,
        'labels': engytime_labels,
        'n_clusters': engytime_labels.nunique().values[0]
    },{
        'name': 'Hepta',
        'data': hepta,
        'labels': hepta_labels,
        'n_clusters': hepta_labels.nunique().values[0]
    },{
        'name': 'Tetra',
        'data': tetra,
        'labels': tetra_labels,
        'n_clusters': tetra_labels.nunique().values[0]
    },{
        'name': 'Target',
        'data': target,
        'labels': target_labels,
        'n_clusters': target_labels.nunique().values[0]
    },{
        'name': 'TwoDiamonds',
        'data': two_diamonds,
        'labels': two_diamonds_labels,
        'n_clusters': two_diamonds_labels.nunique().values[0]
    },{
        'name': 'WingNut',
        'data': wing_nut,
        'labels': wing_nut_labels,
        'n_clusters': wing_nut_labels.nunique().values[0]
    },{
        'name': 'Iris',
        'data': iris_data,
        'labels': iris_labels,
        'n_clusters': 3
    },{
        'name': 'Wine',
        'data': wine_data,
        'labels': wine_labels,
        'n_clusters': 3
    },{
        'name': 'Uniform',
        'data': uniform_data,
        'labels': uniform_labels,
        'n_clusters': uniform_labels.nunique().values[0]
    },{
        'name': 'Rectangle',
        'data': rectangle_data,
        'labels': rectangle_labels,
        'n_clusters': rectangle_labels.nunique().values[0]
    },{
        'name': 'Gaussian',
        'data': gaussian_data,
        'labels': gaussian_labels,
        'n_clusters': gaussian_labels.nunique().values[0]
    },{
        'name': 'GaussianMix',
        'data': gaussian_mix_data,
        'labels': gaussian_mix_labels,
        'n_clusters': gaussian_mix_labels.nunique().values[0]
    }
]
#Resultados
results_df = []

# %%
import json
# Asegura que el directorio exista antes de guardar el archivo
import os
os.makedirs("results_centroid", exist_ok=True)

def normalize_clusters(labels1, labels2):
    # Create a mapping from labels1 to labels2
    unique_labels1 = np.unique(labels1)
    unique_labels2 = np.unique(labels2)
    
    mapping = {}
    for label1 in unique_labels1:
        # Find the most common label2 for each label1
        mask = (labels1 == label1)
        most_common_label2 = pd.Series(labels2[mask]).mode()[0]
        mapping[label1] = most_common_label2
    
    # Apply the mapping to labels1
    normalized_labels1 = np.array([mapping[label] for label in labels1])
    
    return normalized_labels1  

def compare_clusters(labels1, labels2):
    # Create a contingency table
    contingency_table = pd.crosstab(labels1, labels2)
    print("Contingency Table:")
    print(contingency_table)

    # Calculate the Pearson correlation coefficient
    corr, _ = pearsonr(labels1, labels2)
    print(f"Pearson correlation coefficient: {corr}")

#Iteramos sobre los datasets
# testear al menos 10 casoss, evaluar diferencias con Ricardo
# buscar definiciones de interpretaabilidad y como lo miden
for i in range(20):
    for dataset in datasets:
        print(f"Processing dataset: {dataset['name']} ({i+1}/20)")
        
        n_clusters = dataset['n_clusters']
        data = dataset['data']
        labels = dataset['labels'].values.ravel()
        #KMeans
        kmeans = KMeans(n_clusters=n_clusters)
        kmeans_labels = kmeans.fit_predict(data)
        kmeans_silhouette = silhouette_score(data, kmeans_labels)
        kmeans_dunn = dunn_index(data, kmeans_labels)
        kmeans_rand = adjusted_rand_score(labels, kmeans_labels)
        kmeans_pearson = pearsonr(labels, kmeans_labels)
        results_df = results_df + [{
            'Dataset': dataset['name'],
            'Algorithm': 'KMeans',
            'Silhouette': kmeans_silhouette,
            'Dunn': kmeans_dunn,
            'Rand': kmeans_rand,
            'Pearson': kmeans_pearson[0]
        }]

        #DBSCAN
        dbscan = DBSCAN(eps=0.5)
        dbscan_labels = dbscan.fit_predict(data)
        if len(np.unique(dbscan_labels)) > 1:
            dbscan_silhouette = silhouette_score(data, dbscan_labels)
            dbscan_dunn = dunn_index(data, dbscan_labels)
            dbscan_rand = adjusted_rand_score(labels, dbscan_labels)
            dbscan_pearson = pearsonr(labels, dbscan_labels)
        else:
            dbscan_silhouette = 0
            dbscan_dunn = 0
            dbscan_rand = 0
            dbscan_pearson = [0, 0]
        results_df = results_df + [{
            'Dataset': dataset['name'],
            'Algorithm': 'DBSCAN',
            'Silhouette': dbscan_silhouette,
            'Dunn': dbscan_dunn,
            'Rand': dbscan_rand,
            'Pearson': dbscan_pearson[0]
        }]

        #Agglomerative
        agglomerative = AgglomerativeClustering(n_clusters=n_clusters)
        agglomerative_labels = agglomerative.fit_predict(data)
        agglomerative_silhouette = silhouette_score(data, agglomerative_labels)
        agglomerative_dunn = dunn_index(data, agglomerative_labels)
        agglomerative_rand = adjusted_rand_score(labels, agglomerative_labels)
        agglomerative_pearson = pearsonr(labels, agglomerative_labels)
        results_df = results_df + [{
            'Dataset': dataset['name'],
            'Algorithm': 'Agglomerative',
            'Silhouette': agglomerative_silhouette,
            'Dunn': agglomerative_dunn,
            'Rand': agglomerative_rand,
            'Pearson': agglomerative_pearson[0]
        }]
        
        #DSC de Kmeans
        X_values = data.values
        DSC = DSClassifierMultiQ(n_clusters, min_iter=20, max_iter=200, debug_mode=True, lossfn="MSE", num_workers=0, min_dloss=1e-7, precompute_rules=True)
        losses, epoch, dt = DSC.fit(X_values, kmeans_labels, add_single_rules=True, single_rules_breaks=3, add_mult_rules=False, column_names=data.columns, print_every_epochs=1,)
        #calculamos el silhouette score con las predicciones de DSC
        predictions = DSC.predict(X_values)
        dsc_silhouette = silhouette_score(X_values, predictions)
        dsc_dunn = dunn_index(X_values, predictions)
        dsc_ari = adjusted_rand_score(labels, predictions)
        dsc_pearson = pearsonr(labels, predictions)
        results_df = results_df + [{
            'Dataset': dataset['name'],
            'Algorithm': 'DSC',
            'Silhouette': dsc_silhouette,
            'Dunn': dsc_dunn,
            'Rand': dsc_ari,
            'Pearson': dsc_pearson[0]
        }]
        
        """ #Combinamos los labels de KMeans, Agglomerative y DBSCAN, este ultimo solo en caso de que tenga el mismo numero de clusters, para esto usamos la normalizacion de etiquetas
        #print("Comparing clusters...")
        
        #compare_clusters(kmeans_labels, agglomerative_labels)
        normalized_kmeans_labels = normalize_clusters(kmeans_labels, agglomerative_labels)
        #compare_clusters(normalized_kmeans_labels, agglomerative_labels)
        combined_labels = np.concatenate((normalized_kmeans_labels, agglomerative_labels), axis=0)
        X_combined = np.concatenate((X_values, X_values), axis=0)
        # Entrenamos DSC con los labels combinados
        DSC_combined = DSClassifierMultiQ(n_clusters, min_iter=20, max_iter=200, debug_mode=True, lossfn="MSE", num_workers=0, min_dloss=1e-7, precompute_rules=True)
        losses, epoch, dt = DSC_combined.fit(X_combined, combined_labels, add_single_rules=True, single_rules_breaks=3, add_mult_rules=False, column_names=data.columns, print_every_epochs=1,)
        #calculamos el silhouette score con las predicciones de DSC
        predictions_combined = DSC_combined.predict(X_combined)
        dsc_combined_silhouette = silhouette_score(X_combined, predictions_combined)
        dsc_combined_dunn = dunn_index(X_combined, predictions_combined)
        dsc_combined_ari = adjusted_rand_score(combined_labels, predictions_combined)
        dsc_combined_pearson = pearsonr(combined_labels, predictions_combined)
        results_df = results_df + [{
            'Dataset': dataset['name'],
            'Algorithm': 'DSC_Combined',
            'Silhouette': dsc_combined_silhouette,
            'Dunn': dsc_combined_dunn,
            'Rand': dsc_combined_ari,
            'Pearson': dsc_combined_pearson[0]
        }] """
        
        # Print results for the current dataset
        print("Dataset: ", dataset['name'])
        print("-----------------------------")
        print("KMeans: ", kmeans_silhouette, kmeans_dunn, kmeans_rand, kmeans_pearson[0])
        print("DBSCAN: ", dbscan_silhouette, dbscan_dunn, dbscan_rand, dbscan_pearson[0])
        print("Agglomerative: ", agglomerative_silhouette, agglomerative_dunn, agglomerative_rand, agglomerative_pearson[0])
        print("DSC: ", dsc_silhouette, dsc_dunn, dsc_ari, dsc_pearson[0])
        #print("DSC Combined: ", dsc_combined_silhouette, dsc_combined_dunn, dsc_combined_ari, dsc_combined_pearson[0])
        # Guarda los centroides de KMeans en un diccionario
        kmeans_centroids = []
        for idx, centroid in enumerate(kmeans.cluster_centers_):
            centroid_dict = {feature_name: float(value) for feature_name, value in zip(data.columns, centroid)}
            pred, cls, df_rls, builder = DSC.predict_explain(centroid)
            kmeans_centroids.append({"centroid": idx, "values": centroid_dict, "prediction": pred, "class": cls, "rules": df_rls.to_dict(orient='records')})
            
        # Obtiene las reglas más importantes de DSC
        rules = DSC.find_most_important_rules(threshold=0.01)

        
        # Guarda la información en un diccionario y luego en un archivo JSON
        info_dict = {
            "dataset": dataset['name'],
            "kmeans_centroids": kmeans_centroids,
            "dsc_rules": rules
        }
        with open(f"results_centroid/info_{dataset['name']}_{i}.json", "w") as f:
            json.dump(info_dict, f, indent=4, default=str)
        print("-----------------------------")
    #save results
    results = pd.DataFrame(results_df)
    results.to_csv('results_centroid/results'+str(i)+'.csv', index=False)
    results_df = []
# Out:
# Processing dataset: Atom (1/20)
# Optimization started
# Processing epoch	200	0.0337
# Training time: 27.45s, epochs: 200
#
# Least training loss reached: 0.033
# Dataset:  Atom
# -----------------------------
# KMeans:  0.4174755342972209 0.03231027991438114 0.19511197741600156 -0.5330189014262895
# DBSCAN:  0 0 0 0
# Agglomerative:  0.41073709133177916 0.08623451728951541 0.09862621818643041 -0.4323697725073315
# DSC:  0.4136409972773324 0.040079469474647786 0.15932661957011873 -0.49999999999999994
# -----------------------------
# Processing dataset: Chainlink (1/20)
# Optimization started
# Processing epoch	200	0.0247
# Training time: 34.03s, epochs: 200
#
# Least training loss reached: 0.024
# Dataset:  Chainlink
# -----------------------------
# KMeans:  0.3573143551526814 0.018168506721606987 0.0939570501002004 -0.30800000000000005
# DBSCAN:  0.16665067817267834 0.37189737642279397 1.0 1.0
# Agglomerative:  0.3399813559048249 0.03920914359049763 0.35706442581215536 -0.6530953403124256
# DSC:  0.3572088830888027 0.018168506721606987 0.09150661175941303 -0.30400243202918437
# -----------------------------
# Processing dataset: EngyTime (1/20)
# Optimization started
# Processing epoch	200	0.0466
# Training time: 133.37s, epochs: 200
#
# Least training loss reached: 0.046
# Dataset:  EngyTime
# -----------------------------
# KMeans:  0.42460756671846933 0.0038872441759214404 0.8159427516410109 -0.9044427472201408
# DBSCAN:  0.4511335999702433 0.022944704031592777 -1.8752208275137675e-06 0.012795300381519263
# Agglomerative:  0.39934679304255377 0.004629677576555305 0.7184533725930805 0.8539403328927153
# DSC:  0.4139419071080529 0.003372573133298274 0.7604481583273094 -0.8722716465975897
# -----------------------------
# Processing dataset: Hepta (1/20)
# Optimization started
# Processing epoch	76	0.0336
# Training time: 2.62s, epochs: 76
#
# Least training loss reached: 0.039
# Dataset:  Hepta
# -----------------------------
# KMeans:  0.7019231989948803 1.065010037278373 1.0 0.5063964598454868
# DBSCAN:  0.1075426321041714 0.027838598703172145 0.31328213511722036 0.2978287037296722
# Agglomerative:  0.7019231989948803 1.065010037278373 1.0 -0.6502804354998348
# DSC:  0.7019231989948803 1.065010037278373 1.0 0.5063964598454868
# -----------------------------
# Processing dataset: Tetra (1/20)
# Optimization started
# Processing epoch	149	0.0112
# Training time: 9.88s, epochs: 149
#
# Least training loss reached: 0.011
# Dataset:  Tetra
# -----------------------------
# KMeans:  0.5057889289788572 0.22286832447315746 1.0 -0.3999999999999997
# DBSCAN:  0 0 0 0
# Agglomerative:  0.4952113887827159 0.1433076002637819 0.9672676330087653 0.015008444625821404
# DSC:  0.4915647724834497 0.06492093768997717 0.9604834847820484 -0.3932496091866091
# -----------------------------
# Processing dataset: Target (1/20)
# Optimization started
# Processing epoch	181	0.0127
# Training time: 23.71s, epochs: 181
#
# Least training loss reached: 0.013
# Dataset:  Target
# -----------------------------
# KMeans:  0.5756688224309883 0.01651090664220408 0.6344038849082971 0.1796207779958657
# DBSCAN:  0.27620474177731674 0.11689895855783064 0.999634881516244 0.526597696226726
# Agglomerative:  0.5683249608036377 0.044301181765109374 0.6387791202472747 -0.6144108628824496
# DSC:  0.5503997267447185 0.014764625818190802 0.6404940650082388 0.07054975349589647
# -----------------------------
# Processing dataset: TwoDiamonds (1/20)
# Optimization started
# Processing epoch	200	0.0271
# Training time: 27.27s, epochs: 200
#
# Least training loss reached: 0.027
# Dataset:  TwoDiamonds
# -----------------------------
# KMeans:  0.6305972114000131 0.04499999999999993 1.0 0.9999999999999998
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6305972114000131 0.04499999999999993 1.0 -0.9999999999999998
# DSC:  0.6305972114000131 0.04499999999999993 1.0 0.9999999999999998
# -----------------------------
# Processing dataset: WingNut (1/20)
# Optimization started
# Processing epoch	200	0.0434
# Training time: 33.90s, epochs: 200
#
# Least training loss reached: 0.043
# Dataset:  WingNut
# -----------------------------
# KMeans:  0.4602622190852718 0.01984498237527709 0.8558471895050299 -0.9251968503937008
# DBSCAN:  0 0 0 0
# Agglomerative:  0.43491039594216246 0.03016708956447158 0.6011477451948987 -0.7755905511811023
# DSC:  0.4482302192929621 0.08320502943378437 1.0 -1.0
# -----------------------------
# Processing dataset: Iris (1/20)
# Optimization started
# Processing epoch	200	0.0222
# Training time: 4.59s, epochs: 200
#
# Least training loss reached: 0.022
# Dataset:  Iris
# -----------------------------
# KMeans:  0.5511916046195919 0.10943513103291669 0.7163421126838476 -0.6096805124846351
# DBSCAN:  0.48603419703456857 0.07543555587646832 0.5206185241703302 0.36771246459370666
# Agglomerative:  0.5543236611296419 0.1127947086987354 0.7311985567707746 0.20544090417863603
# DSC:  0.5481277835097936 0.10088665446106332 0.7445264308738749 -0.6050854150069594
# -----------------------------
# Processing dataset: Wine (1/20)
# Optimization started
# Processing epoch	200	0.0423
# Training time: 5.85s, epochs: 200
#
# Least training loss reached: 0.042
# Dataset:  Wine
# -----------------------------
# KMeans:  0.5595823478987213 0.014749468689460535 0.3517721516862617 -0.49436379276374254
# DBSCAN:  0 0 0 0
# Agglomerative:  0.5644796401732068 0.022374511405772082 0.36840191587483156 0.5725250629992938
# DSC:  0.5076913477719204 0.008545830157896025 0.35969275134598705 -0.5762304921210947
# -----------------------------
# Processing dataset: Uniform (1/20)
# Optimization started
# Processing epoch	200	0.0294
# Training time: 15.66s, epochs: 200
#
# Least training loss reached: 0.029
# Dataset:  Uniform
# -----------------------------
# KMeans:  0.6092631731974764 0.0076467486244800025 0.9681923665792226 -0.9841108417256753
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6008471293304483 0.014950812622520028 0.6265259590119457 -0.8079466429027214
# DSC:  0.6092812517586981 0.011087505148872884 0.9603206157858745 -0.9801803569660551
# -----------------------------
# Processing dataset: Rectangle (1/20)
# Optimization started
# Processing epoch	200	0.0255
# Training time: 42.35s, epochs: 200
#
# Least training loss reached: 0.025
# Dataset:  Rectangle
# -----------------------------
# KMeans:  0.439638954527144 0.1482489233833969 1.0 1.0
# DBSCAN:  0 0 0 0
# Agglomerative:  0.439638954527144 0.1482489233833969 1.0 1.0
# DSC:  0.439638954527144 0.1482489233833969 1.0 1.0
# -----------------------------
# Processing dataset: Gaussian (1/20)
# Optimization started
# Processing epoch	200	0.0304
# Training time: 15.73s, epochs: 200
#
# Least training loss reached: 0.030
# Dataset:  Gaussian
# -----------------------------
# KMeans:  0.6435277436707083 0.09856924495839288 0.984032 -0.9920000000000003
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6435277436707083 0.09856924495839288 0.984032 -0.9920000000000003
# DSC:  0.6228243739102449 0.012432576744397522 0.8909174116090074 -0.9440302094500612
# -----------------------------
# Processing dataset: GaussianMix (1/20)
# Optimization started
# Processing epoch	200	0.0131
# Training time: 19.34s, epochs: 200
#
# Least training loss reached: 0.013
# Dataset:  GaussianMix
# -----------------------------
# KMeans:  0.6841696612519849 0.10389054380912274 1.0 1.0
# DBSCAN:  0.6048572335715502 0.20904348659001887 0.5706093189964158 0.0
# Agglomerative:  0.6841696612519849 0.10389054380912274 1.0 0.5
# DSC:  0.6816804797318925 0.0654664827632236 0.9850626884924543 0.9850082084359391
# -----------------------------
# Processing dataset: Atom (2/20)
# Optimization started
# Processing epoch	200	0.0390
# Training time: 26.35s, epochs: 200
#
# Least training loss reached: 0.039
# Dataset:  Atom
# -----------------------------
# KMeans:  0.41762078590995527 0.03848845969442412 0.18206807775637826 -0.5214020477419581
# DBSCAN:  0 0 0 0
# Agglomerative:  0.41073709133177916 0.08623451728951541 0.09862621818643041 -0.4323697725073315
# DSC:  0.4136409972773324 0.040079469474647786 0.15932661957011873 -0.49999999999999994
# -----------------------------
# Processing dataset: Chainlink (2/20)
# Optimization started
# Processing epoch	200	0.0281
# Training time: 33.27s, epochs: 200
#
# Least training loss reached: 0.028
# Dataset:  Chainlink
# -----------------------------
# KMeans:  0.35730946464884406 0.018168506721606987 0.09272782327563998 -0.306000612001836
# DBSCAN:  0.16665067817267834 0.37189737642279397 1.0 1.0
# Agglomerative:  0.3399813559048249 0.03920914359049763 0.35706442581215536 -0.6530953403124256
# DSC:  0.3572088830888027 0.018168506721606987 0.09150661175941303 -0.30400243202918437
# -----------------------------
# Processing dataset: EngyTime (2/20)
# Optimization started
# Processing epoch	200	0.0473
# Training time: 131.79s, epochs: 200
#
# Least training loss reached: 0.047
# Dataset:  EngyTime
# -----------------------------
# KMeans:  0.42458379265139157 0.0017536764885264526 0.815060637690859 -0.9040667693054494
# DBSCAN:  0.4511335999702433 0.022944704031592777 -1.8752208275137675e-06 0.012795300381519263
# Agglomerative:  0.39934679304255377 0.004629677576555305 0.7184533725930805 0.8539403328927153
# DSC:  0.4139419071080529 0.003372573133298274 0.7604481583273094 -0.8722716465975897
# -----------------------------
# Processing dataset: Hepta (2/20)
# Optimization started
# Processing epoch	76	0.0339
# Training time: 2.52s, epochs: 76
#
# Least training loss reached: 0.039
# Dataset:  Hepta
# -----------------------------
# KMeans:  0.7019231989948803 1.065010037278373 1.0 0.08428879475802993
# DBSCAN:  0.1075426321041714 0.027838598703172145 0.31328213511722036 0.2978287037296722
# Agglomerative:  0.7019231989948803 1.065010037278373 1.0 -0.6502804354998348
# DSC:  0.7019231989948803 1.065010037278373 1.0 0.08428879475802993
# -----------------------------
# Processing dataset: Tetra (2/20)
# Optimization started
# Processing epoch	165	0.0099
# Training time: 10.58s, epochs: 165
#
# Least training loss reached: 0.010
# Dataset:  Tetra
# -----------------------------
# KMeans:  0.5057889289788572 0.22286832447315746 1.0 -0.5999999999999999
# DBSCAN:  0 0 0 0
# Agglomerative:  0.4952113887827159 0.1433076002637819 0.9672676330087653 0.015008444625821404
# DSC:  0.5020330024147078 0.08081231954814541 0.9866666397310955 -0.6010135229564014
# -----------------------------
# Processing dataset: Target (2/20)
# Optimization started
# Processing epoch	170	0.0094
# Training time: 21.64s, epochs: 170
#
# Least training loss reached: 0.009
# Dataset:  Target
# -----------------------------
# KMeans:  0.5783094879515287 0.013809758253079752 0.6366752622162033 0.7001492257098935
# DBSCAN:  0.27620474177731674 0.11689895855783064 0.999634881516244 0.526597696226726
# Agglomerative:  0.5683249608036377 0.044301181765109374 0.6387791202472747 -0.6144108628824496
# DSC:  0.5684264736595016 0.017875144132636186 0.6386565741208261 0.6938210565544869
# -----------------------------
# Processing dataset: TwoDiamonds (2/20)
# Optimization started
# Processing epoch	200	0.0330
# Training time: 26.22s, epochs: 200
#
# Least training loss reached: 0.033
# Dataset:  TwoDiamonds
# -----------------------------
# KMeans:  0.6305972114000131 0.04499999999999993 1.0 -0.9999999999999998
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6305972114000131 0.04499999999999993 1.0 -0.9999999999999998
# DSC:  0.6305972114000131 0.04499999999999993 1.0 -0.9999999999999998
# -----------------------------
# Processing dataset: WingNut (2/20)
# Optimization started
# Processing epoch	200	0.0430
# Training time: 33.80s, epochs: 200
#
# Least training loss reached: 0.043
# Dataset:  WingNut
# -----------------------------
# KMeans:  0.4602403628385199 0.01984498237527709 0.859497168372491 -0.9271671507223962
# DBSCAN:  0 0 0 0
# Agglomerative:  0.43491039594216246 0.03016708956447158 0.6011477451948987 -0.7755905511811023
# DSC:  0.4482302192929621 0.08320502943378437 1.0 -1.0
# -----------------------------
# Processing dataset: Iris (2/20)
# Optimization started
# Processing epoch	200	0.0228
# Training time: 4.59s, epochs: 200
#
# Least training loss reached: 0.023
# Dataset:  Iris
# -----------------------------
# KMeans:  0.5511916046195919 0.10943513103291669 0.7163421126838476 0.6096805124846351
# DBSCAN:  0.48603419703456857 0.07543555587646832 0.5206185241703302 0.36771246459370666
# Agglomerative:  0.5543236611296419 0.1127947086987354 0.7311985567707746 0.20544090417863603
# DSC:  0.5481277835097936 0.10088665446106332 0.7445264308738749 0.6050854150069594
# -----------------------------
# Processing dataset: Wine (2/20)
# Optimization started
# Processing epoch	200	0.0302
# Training time: 5.84s, epochs: 200
#
# Least training loss reached: 0.030
# Dataset:  Wine
# -----------------------------
# KMeans:  0.5711381937868838 0.01626043915542385 0.37111371823084754 -0.029116180722158463
# DBSCAN:  0 0 0 0
# Agglomerative:  0.5644796401732068 0.022374511405772082 0.36840191587483156 0.5725250629992938
# DSC:  0.5514369722690448 0.006738631513339247 0.37530970581500783 0.025944315788736683
# -----------------------------
# Processing dataset: Uniform (2/20)
# Optimization started
# Processing epoch	200	0.0239
# Training time: 15.69s, epochs: 200
#
# Least training loss reached: 0.024
# Dataset:  Uniform
# -----------------------------
# KMeans:  0.6092631731974764 0.0076467486244800025 0.9681923665792226 0.9841108417256753
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6008471293304483 0.014950812622520028 0.6265259590119457 -0.8079466429027214
# DSC:  0.6092812517586981 0.011087505148872884 0.9603206157858745 0.9801803569660551
# -----------------------------
# Processing dataset: Rectangle (2/20)
# Optimization started
# Processing epoch	200	0.0249
# Training time: 42.95s, epochs: 200
#
# Least training loss reached: 0.025
# Dataset:  Rectangle
# -----------------------------
# KMeans:  0.439638954527144 0.1482489233833969 1.0 1.0
# DBSCAN:  0 0 0 0
# Agglomerative:  0.439638954527144 0.1482489233833969 1.0 1.0
# DSC:  0.439638954527144 0.1482489233833969 1.0 1.0
# -----------------------------
# Processing dataset: Gaussian (2/20)
# Optimization started
# Processing epoch	200	0.0261
# Training time: 16.32s, epochs: 200
#
# Least training loss reached: 0.026
# Dataset:  Gaussian
# -----------------------------
# KMeans:  0.6435277436707083 0.09856924495839288 0.984032 0.9920000000000003
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6435277436707083 0.09856924495839288 0.984032 -0.9920000000000003
# DSC:  0.6415734519506503 0.0445832282181824 0.968192261115854 0.9840314895115045
# -----------------------------
# Processing dataset: GaussianMix (2/20)
# Optimization started
# Processing epoch	200	0.0124
# Training time: 19.55s, epochs: 200
#
# Least training loss reached: 0.012
# Dataset:  GaussianMix
# -----------------------------
# KMeans:  0.6841696612519849 0.10389054380912274 1.0 1.0
# DBSCAN:  0.6048572335715502 0.20904348659001887 0.5706093189964158 0.0
# Agglomerative:  0.6841696612519849 0.10389054380912274 1.0 0.5
# DSC:  0.6816804797318925 0.0654664827632236 0.9850626884924543 0.9850082084359391
# -----------------------------
# Processing dataset: Atom (3/20)
# Optimization started
# Processing epoch	200	0.0283
# Training time: 27.60s, epochs: 200
#
# Least training loss reached: 0.028
# Dataset:  Atom
# -----------------------------
# KMeans:  0.42206675649084574 0.02943757230277807 0.14564469269222696 0.48628802501877577
# DBSCAN:  0 0 0 0
# Agglomerative:  0.41073709133177916 0.08623451728951541 0.09862621818643041 -0.4323697725073315
# DSC:  0.42112349590542136 0.0424033296098608 0.13440630315586855 0.47446270087079656
# -----------------------------
# Processing dataset: Chainlink (3/20)
# Optimization started
# Processing epoch	200	0.0291
# Training time: 33.70s, epochs: 200
#
# Least training loss reached: 0.029
# Dataset:  Chainlink
# -----------------------------
# KMeans:  0.3576634859293782 0.011819464263069736 0.10022375900972008 -0.3180769839462999
# DBSCAN:  0.16665067817267834 0.37189737642279397 1.0 1.0
# Agglomerative:  0.3399813559048249 0.03920914359049763 0.35706442581215536 -0.6530953403124256
# DSC:  0.3572088830888027 0.018168506721606987 0.09150661175941303 -0.30400243202918437
# -----------------------------
# Processing dataset: EngyTime (3/20)
# Optimization started
# Processing epoch	200	0.0459
# Training time: 132.11s, epochs: 200
#
# Least training loss reached: 0.046
# Dataset:  EngyTime
# -----------------------------
# KMeans:  0.42458379265139157 0.0017536764885264526 0.815060637690859 -0.9040667693054494
# DBSCAN:  0.4511335999702433 0.022944704031592777 -1.8752208275137675e-06 0.012795300381519263
# Agglomerative:  0.39934679304255377 0.004629677576555305 0.7184533725930805 0.8539403328927153
# DSC:  0.4139419071080529 0.003372573133298274 0.7604481583273094 -0.8722716465975897
# -----------------------------
# Processing dataset: Hepta (3/20)
# Optimization started
# Processing epoch	76	0.0345
# Training time: 2.51s, epochs: 76
#
# Least training loss reached: 0.040
# Dataset:  Hepta
# -----------------------------
# KMeans:  0.7019231989948803 1.065010037278373 1.0 -0.3180705488034362
# DBSCAN:  0.1075426321041714 0.027838598703172145 0.31328213511722036 0.2978287037296722
# Agglomerative:  0.7019231989948803 1.065010037278373 1.0 -0.6502804354998348
# DSC:  0.6597870130847976 0.05040544878487828 0.9680721788115464 -0.31517679431538104
# -----------------------------
# Processing dataset: Tetra (3/20)
# Optimization started
# Processing epoch	200	0.0068
# Training time: 12.79s, epochs: 200
#
# Least training loss reached: 0.007
# Dataset:  Tetra
# -----------------------------
# KMeans:  0.5057889289788572 0.22286832447315746 1.0 5.551115123125783e-17
# DBSCAN:  0 0 0 0
# Agglomerative:  0.4952113887827159 0.1433076002637819 0.9672676330087653 0.015008444625821404
# DSC:  0.5020330024147078 0.08081231954814541 0.9866666397310955 0.005000112503797033
# -----------------------------
# Processing dataset: Target (3/20)
# Optimization started
# Processing epoch	193	0.0102
# Training time: 24.70s, epochs: 193
#
# Least training loss reached: 0.010
# Dataset:  Target
# -----------------------------
# KMeans:  0.5824838944072853 0.023540382547916405 0.6357711409365294 0.6953252305933639
# DBSCAN:  0.27620474177731674 0.11689895855783064 0.999634881516244 0.526597696226726
# Agglomerative:  0.5683249608036377 0.044301181765109374 0.6387791202472747 -0.6144108628824496
# DSC:  0.568719126609967 0.017756727402144897 0.6383471968305066 0.684196395672823
# -----------------------------
# Processing dataset: TwoDiamonds (3/20)
# Optimization started
# Processing epoch	200	0.0291
# Training time: 26.11s, epochs: 200
#
# Least training loss reached: 0.029
# Dataset:  TwoDiamonds
# -----------------------------
# KMeans:  0.6305972114000131 0.04499999999999993 1.0 -0.9999999999999998
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6305972114000131 0.04499999999999993 1.0 -0.9999999999999998
# DSC:  0.6305972114000131 0.04499999999999993 1.0 -0.9999999999999998
# -----------------------------
# Processing dataset: WingNut (3/20)
# Optimization started
# Processing epoch	200	0.0504
# Training time: 33.64s, epochs: 200
#
# Least training loss reached: 0.050
# Dataset:  WingNut
# -----------------------------
# KMeans:  0.4602403628385199 0.01984498237527709 0.859497168372491 0.9271671507223962
# DBSCAN:  0 0 0 0
# Agglomerative:  0.43491039594216246 0.03016708956447158 0.6011477451948987 -0.7755905511811023
# DSC:  0.4482302192929621 0.08320502943378437 1.0 1.0
# -----------------------------
# Processing dataset: Iris (3/20)
# Optimization started
# Processing epoch	200	0.0205
# Training time: 4.61s, epochs: 200
#
# Least training loss reached: 0.020
# Dataset:  Iris
# -----------------------------
# KMeans:  0.5528190123564095 0.09880739332808099 0.7302382722834697 0.22434967952320123
# DBSCAN:  0.48603419703456857 0.07543555587646832 0.5206185241703302 0.36771246459370666
# Agglomerative:  0.5543236611296419 0.1127947086987354 0.7311985567707746 0.20544090417863603
# DSC:  0.5481277835097936 0.10088665446106332 0.7445264308738749 0.22513144257068346
# -----------------------------
# Processing dataset: Wine (3/20)
# Optimization started
# Processing epoch	200	0.0273
# Training time: 5.92s, epochs: 200
#
# Least training loss reached: 0.027
# Dataset:  Wine
# -----------------------------
# KMeans:  0.5711381937868838 0.01626043915542385 0.37111371823084754 -0.029116180722158463
# DBSCAN:  0 0 0 0
# Agglomerative:  0.5644796401732068 0.022374511405772082 0.36840191587483156 0.5725250629992938
# DSC:  0.5514369722690448 0.006738631513339247 0.37530970581500783 0.025944315788736683
# -----------------------------
# Processing dataset: Uniform (3/20)
# Optimization started
# Processing epoch	200	0.0279
# Training time: 15.81s, epochs: 200
#
# Least training loss reached: 0.028
# Dataset:  Uniform
# -----------------------------
# KMeans:  0.6090703940135522 0.004129051664811543 0.9840320578693613 -0.992021573499599
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6008471293304483 0.014950812622520028 0.6265259590119457 -0.8079466429027214
# DSC:  0.6092812517586981 0.011087505148872884 0.9603206157858745 -0.9801803569660551
# -----------------------------
# Processing dataset: Rectangle (3/20)
# Optimization started
# Processing epoch	200	0.0243
# Training time: 42.62s, epochs: 200
#
# Least training loss reached: 0.024
# Dataset:  Rectangle
# -----------------------------
# KMeans:  0.439638954527144 0.1482489233833969 1.0 -1.0
# DBSCAN:  0 0 0 0
# Agglomerative:  0.439638954527144 0.1482489233833969 1.0 1.0
# DSC:  0.439638954527144 0.1482489233833969 1.0 -1.0
# -----------------------------
# Processing dataset: Gaussian (3/20)
# Optimization started
# Processing epoch	200	0.0262
# Training time: 15.84s, epochs: 200
#
# Least training loss reached: 0.026
# Dataset:  Gaussian
# -----------------------------
# KMeans:  0.6435277436707083 0.09856924495839288 0.984032 0.9920000000000003
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6435277436707083 0.09856924495839288 0.984032 -0.9920000000000003
# DSC:  0.6322600837125726 0.014631846218953816 0.9291541356288306 0.9643781103434133
# -----------------------------
# Processing dataset: GaussianMix (3/20)
# Optimization started
# Processing epoch	200	0.0117
# Training time: 19.93s, epochs: 200
#
# Least training loss reached: 0.012
# Dataset:  GaussianMix
# -----------------------------
# KMeans:  0.6841696612519849 0.10389054380912274 1.0 1.0
# DBSCAN:  0.6048572335715502 0.20904348659001887 0.5706093189964158 0.0
# Agglomerative:  0.6841696612519849 0.10389054380912274 1.0 0.5
# DSC:  0.6816804797318925 0.0654664827632236 0.9850626884924543 0.9850082084359391
# -----------------------------
# Processing dataset: Atom (4/20)
# Optimization started
# Processing epoch	200	0.0374
# Training time: 26.90s, epochs: 200
#
# Least training loss reached: 0.037
# Dataset:  Atom
# -----------------------------
# KMeans:  0.42206675649084574 0.02943757230277807 0.14564469269222696 -0.48628802501877577
# DBSCAN:  0 0 0 0
# Agglomerative:  0.41073709133177916 0.08623451728951541 0.09862621818643041 -0.4323697725073315
# DSC:  0.42112349590542136 0.0424033296098608 0.13440630315586855 -0.4744627008707966
# -----------------------------
# Processing dataset: Chainlink (4/20)
# Optimization started
# Processing epoch	200	0.0306
# Training time: 33.64s, epochs: 200
#
# Least training loss reached: 0.030
# Dataset:  Chainlink
# -----------------------------
# KMeans:  0.3573143551526814 0.018168506721606987 0.0939570501002004 0.30800000000000005
# DBSCAN:  0.16665067817267834 0.37189737642279397 1.0 1.0
# Agglomerative:  0.3399813559048249 0.03920914359049763 0.35706442581215536 -0.6530953403124256
# DSC:  0.3572088830888027 0.018168506721606987 0.09150661175941303 0.30400243202918437
# -----------------------------
# Processing dataset: EngyTime (4/20)
# Optimization started
# Processing epoch	200	0.0444
# Training time: 132.04s, epochs: 200
#
# Least training loss reached: 0.044
# Dataset:  EngyTime
# -----------------------------
# KMeans:  0.42458379265139157 0.0017536764885264526 0.815060637690859 0.9040667693054494
# DBSCAN:  0.4511335999702433 0.022944704031592777 -1.8752208275137675e-06 0.012795300381519263
# Agglomerative:  0.39934679304255377 0.004629677576555305 0.7184533725930805 0.8539403328927153
# DSC:  0.4139419071080529 0.003372573133298274 0.7604481583273094 0.8722716465975897
# -----------------------------
# Processing dataset: Hepta (4/20)
# Optimization started
# Processing epoch	77	0.0329
# Training time: 2.68s, epochs: 77
#
# Least training loss reached: 0.038
# Dataset:  Hepta
# -----------------------------
# KMeans:  0.7019231989948803 1.065010037278373 1.0 -0.440448696799736
# DBSCAN:  0.1075426321041714 0.027838598703172145 0.31328213511722036 0.2978287037296722
# Agglomerative:  0.7019231989948803 1.065010037278373 1.0 -0.6502804354998348
# DSC:  0.7019231989948803 1.065010037278373 1.0 -0.440448696799736
# -----------------------------
# Processing dataset: Tetra (4/20)
# Optimization started
# Processing epoch	149	0.0121
# Training time: 9.52s, epochs: 149
#
# Least training loss reached: 0.012
# Dataset:  Tetra
# -----------------------------
# KMeans:  0.5057889289788572 0.22286832447315746 1.0 -0.3999999999999997
# DBSCAN:  0 0 0 0
# Agglomerative:  0.4952113887827159 0.1433076002637819 0.9672676330087653 0.015008444625821404
# DSC:  0.4915647724834497 0.06492093768997717 0.9604834847820484 -0.41102472895496944
# -----------------------------
# Processing dataset: Target (4/20)
# Optimization started
# Processing epoch	165	0.0098
# Training time: 21.22s, epochs: 165
#
# Least training loss reached: 0.010
# Dataset:  Target
# -----------------------------
# KMeans:  0.5783094879515287 0.013809758253079752 0.6366752622162033 0.6908374358292423
# DBSCAN:  0.27620474177731674 0.11689895855783064 0.999634881516244 0.526597696226726
# Agglomerative:  0.5683249608036377 0.044301181765109374 0.6387791202472747 -0.6144108628824496
# DSC:  0.5684264736595016 0.017875144132636186 0.6386565741208261 0.6947451099835437
# -----------------------------
# Processing dataset: TwoDiamonds (4/20)
# Optimization started
# Processing epoch	200	0.0300
# Training time: 26.12s, epochs: 200
#
# Least training loss reached: 0.030
# Dataset:  TwoDiamonds
# -----------------------------
# KMeans:  0.6305972114000131 0.04499999999999993 1.0 -0.9999999999999998
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6305972114000131 0.04499999999999993 1.0 -0.9999999999999998
# DSC:  0.6305972114000131 0.04499999999999993 1.0 -0.9999999999999998
# -----------------------------
# Processing dataset: WingNut (4/20)
# Optimization started
# Processing epoch	200	0.0456
# Training time: 34.21s, epochs: 200
#
# Least training loss reached: 0.045
# Dataset:  WingNut
# -----------------------------
# KMeans:  0.460240362836918 0.01984498237527709 0.859497168372491 0.9271671507223962
# DBSCAN:  0 0 0 0
# Agglomerative:  0.43491039594216246 0.03016708956447158 0.6011477451948987 -0.7755905511811023
# DSC:  0.4482302192929621 0.08320502943378437 1.0 1.0
# -----------------------------
# Processing dataset: Iris (4/20)
# Optimization started
# Processing epoch	200	0.0209
# Training time: 4.70s, epochs: 200
#
# Least training loss reached: 0.021
# Dataset:  Iris
# -----------------------------
# KMeans:  0.5528190123564095 0.09880739332808099 0.7302382722834697 -0.22434967952320115
# DBSCAN:  0.48603419703456857 0.07543555587646832 0.5206185241703302 0.36771246459370666
# Agglomerative:  0.5543236611296419 0.1127947086987354 0.7311985567707746 0.20544090417863603
# DSC:  0.5481277835097936 0.10088665446106332 0.7445264308738749 -0.22513144257068346
# -----------------------------
# Processing dataset: Wine (4/20)
# Optimization started
# Processing epoch	200	0.0301
# Training time: 5.84s, epochs: 200
#
# Least training loss reached: 0.030
# Dataset:  Wine
# -----------------------------
# KMeans:  0.5711381937868838 0.01626043915542385 0.37111371823084754 -0.029116180722158463
# DBSCAN:  0 0 0 0
# Agglomerative:  0.5644796401732068 0.022374511405772082 0.36840191587483156 0.5725250629992938
# DSC:  0.5514369722690448 0.006738631513339247 0.37530970581500783 0.025944315788736683
# -----------------------------
# Processing dataset: Uniform (4/20)
# Optimization started
# Processing epoch	200	0.0253
# Training time: 16.89s, epochs: 200
#
# Least training loss reached: 0.025
# Dataset:  Uniform
# -----------------------------
# KMeans:  0.6092631731974764 0.0076467486244800025 0.9681923665792226 -0.9841108417256753
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6008471293304483 0.014950812622520028 0.6265259590119457 -0.8079466429027214
# DSC:  0.6092812517586981 0.011087505148872884 0.9603206157858745 -0.9801803569660551
# -----------------------------
# Processing dataset: Rectangle (4/20)
# Optimization started
# Processing epoch	200	0.0227
# Training time: 45.12s, epochs: 200
#
# Least training loss reached: 0.022
# Dataset:  Rectangle
# -----------------------------
# KMeans:  0.439638954527144 0.1482489233833969 1.0 -1.0
# DBSCAN:  0 0 0 0
# Agglomerative:  0.439638954527144 0.1482489233833969 1.0 1.0
# DSC:  0.439638954527144 0.1482489233833969 1.0 -1.0
# -----------------------------
# Processing dataset: Gaussian (4/20)
# Optimization started
# Processing epoch	200	0.0262
# Training time: 17.75s, epochs: 200
#
# Least training loss reached: 0.026
# Dataset:  Gaussian
# -----------------------------
# KMeans:  0.6435277436707083 0.09856924495839288 0.984032 -0.9920000000000003
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6435277436707083 0.09856924495839288 0.984032 -0.9920000000000003
# DSC:  0.6415734519506503 0.0445832282181824 0.968192261115854 -0.9840314895115045
# -----------------------------
# Processing dataset: GaussianMix (4/20)
# Optimization started
# Processing epoch	200	0.0141
# Training time: 20.77s, epochs: 200
#
# Least training loss reached: 0.014
# Dataset:  GaussianMix
# -----------------------------
# KMeans:  0.6841696612519849 0.10389054380912274 1.0 -0.5
# DBSCAN:  0.6048572335715502 0.20904348659001887 0.5706093189964158 0.0
# Agglomerative:  0.6841696612519849 0.10389054380912274 1.0 0.5
# DSC:  0.6816804797318925 0.0654664827632236 0.9850626884924543 -0.4931178116115411
# -----------------------------
# Processing dataset: Atom (5/20)
# Optimization started
# Processing epoch	200	0.0307
# Training time: 28.65s, epochs: 200
#
# Least training loss reached: 0.030
# Dataset:  Atom
# -----------------------------
# KMeans:  0.4174755342972209 0.03231027991438114 0.19511197741600156 0.5330189014262895
# DBSCAN:  0 0 0 0
# Agglomerative:  0.41073709133177916 0.08623451728951541 0.09862621818643041 -0.4323697725073315
# DSC:  0.4136409972773324 0.040079469474647786 0.15932661957011873 0.49999999999999994
# -----------------------------
# Processing dataset: Chainlink (5/20)
# Optimization started
# Processing epoch	200	0.0369
# Training time: 35.86s, epochs: 200
#
# Least training loss reached: 0.037
# Dataset:  Chainlink
# -----------------------------
# KMeans:  0.3575260895869045 0.010060645216962906 0.09643959301389383 -0.31200998447925754
# DBSCAN:  0.16665067817267834 0.37189737642279397 1.0 1.0
# Agglomerative:  0.3399813559048249 0.03920914359049763 0.35706442581215536 -0.6530953403124256
# DSC:  0.3572088830888027 0.018168506721606987 0.09150661175941303 -0.30400243202918437
# -----------------------------
# Processing dataset: EngyTime (5/20)
# Optimization started
# Processing epoch	200	0.0459
# Training time: 139.13s, epochs: 200
#
# Least training loss reached: 0.046
# Dataset:  EngyTime
# -----------------------------
# KMeans:  0.42463758764423476 0.0038872441759214404 0.8168253559861115 -0.9049538056309921
# DBSCAN:  0.4511335999702433 0.022944704031592777 -1.8752208275137675e-06 0.012795300381519263
# Agglomerative:  0.39934679304255377 0.004629677576555305 0.7184533725930805 0.8539403328927153
# DSC:  0.4139419071080529 0.003372573133298274 0.7604481583273094 -0.8722716465975897
# -----------------------------
# Processing dataset: Hepta (5/20)
# Optimization started
# Processing epoch	75	0.0340
# Training time: 2.78s, epochs: 75
#
# Least training loss reached: 0.039
# Dataset:  Hepta
# -----------------------------
# KMeans:  0.7019231989948803 1.065010037278373 1.0 0.18981571102989414
# DBSCAN:  0.1075426321041714 0.027838598703172145 0.31328213511722036 0.2978287037296722
# Agglomerative:  0.7019231989948803 1.065010037278373 1.0 -0.6502804354998348
# DSC:  0.7019231989948803 1.065010037278373 1.0 0.18981571102989414
# -----------------------------
# Processing dataset: Tetra (5/20)
# Optimization started
# Processing epoch	162	0.0105
# Training time: 11.08s, epochs: 162
#
# Least training loss reached: 0.010
# Dataset:  Tetra
# -----------------------------
# KMeans:  0.5057889289788572 0.22286832447315746 1.0 -0.19999999999999982
# DBSCAN:  0 0 0 0
# Agglomerative:  0.4952113887827159 0.1433076002637819 0.9672676330087653 0.015008444625821404
# DSC:  0.4915647724834497 0.06492093768997717 0.9604834847820484 -0.21752760044405095
# -----------------------------
# Processing dataset: Target (5/20)
# Optimization started
# Processing epoch	172	0.0148
# Training time: 23.43s, epochs: 172
#
# Least training loss reached: 0.015
# Dataset:  Target
# -----------------------------
# KMeans:  0.5801263096619466 0.022936676532485073 0.6350271573919927 0.14946568705733046
# DBSCAN:  0.27620474177731674 0.11689895855783064 0.999634881516244 0.526597696226726
# Agglomerative:  0.5683249608036377 0.044301181765109374 0.6387791202472747 -0.6144108628824496
# DSC:  0.5636871935218837 0.016787864689482256 0.6388979105520161 0.17464837059237365
# -----------------------------
# Processing dataset: TwoDiamonds (5/20)
# Optimization started
# Processing epoch	200	0.0322
# Training time: 28.01s, epochs: 200
#
# Least training loss reached: 0.032
# Dataset:  TwoDiamonds
# -----------------------------
# KMeans:  0.6305972114000131 0.04499999999999993 1.0 0.9999999999999998
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6305972114000131 0.04499999999999993 1.0 -0.9999999999999998
# DSC:  0.6305972114000131 0.04499999999999993 1.0 0.9999999999999998
# -----------------------------
# Processing dataset: WingNut (5/20)
# Optimization started
# Processing epoch	200	0.0491
# Training time: 37.59s, epochs: 200
#
# Least training loss reached: 0.049
# Dataset:  WingNut
# -----------------------------
# KMeans:  0.460240362836918 0.01984498237527709 0.859497168372491 0.9271671507223962
# DBSCAN:  0 0 0 0
# Agglomerative:  0.43491039594216246 0.03016708956447158 0.6011477451948987 -0.7755905511811023
# DSC:  0.4482302192929621 0.08320502943378437 1.0 1.0
# -----------------------------
# Processing dataset: Iris (5/20)
# Optimization started
# Processing epoch	200	0.0212
# Training time: 5.05s, epochs: 200
#
# Least training loss reached: 0.021
# Dataset:  Iris
# -----------------------------
# KMeans:  0.5511916046195919 0.10943513103291669 0.7163421126838476 0.2236376039494433
# DBSCAN:  0.48603419703456857 0.07543555587646832 0.5206185241703302 0.36771246459370666
# Agglomerative:  0.5543236611296419 0.1127947086987354 0.7311985567707746 0.20544090417863603
# DSC:  0.5481277835097936 0.10088665446106332 0.7445264308738749 0.22513144257068346
# -----------------------------
# Processing dataset: Wine (5/20)
# Optimization started
# Processing epoch	200	0.0437
# Training time: 6.42s, epochs: 200
#
# Least training loss reached: 0.044
# Dataset:  Wine
# -----------------------------
# KMeans:  0.5595823478987213 0.014749468689460535 0.3517721516862617 -0.49436379276374254
# DBSCAN:  0 0 0 0
# Agglomerative:  0.5644796401732068 0.022374511405772082 0.36840191587483156 0.5725250629992938
# DSC:  0.49797956365112167 0.0076147432844006265 0.359887614066436 -0.580541290165044
# -----------------------------
# Processing dataset: Uniform (5/20)
# Optimization started
# Processing epoch	200	0.0271
# Training time: 17.67s, epochs: 200
#
# Least training loss reached: 0.027
# Dataset:  Uniform
# -----------------------------
# KMeans:  0.6090703940135522 0.004129051664811543 0.9840320578693613 -0.992021573499599
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6008471293304483 0.014950812622520028 0.6265259590119457 -0.8079466429027214
# DSC:  0.6092812517586981 0.011087505148872884 0.9603206157858745 -0.9801803569660551
# -----------------------------
# Processing dataset: Rectangle (5/20)
# Optimization started
# Processing epoch	200	0.0250
# Training time: 46.19s, epochs: 200
#
# Least training loss reached: 0.025
# Dataset:  Rectangle
# -----------------------------
# KMeans:  0.439638954527144 0.1482489233833969 1.0 1.0
# DBSCAN:  0 0 0 0
# Agglomerative:  0.439638954527144 0.1482489233833969 1.0 1.0
# DSC:  0.439638954527144 0.1482489233833969 1.0 1.0
# -----------------------------
# Processing dataset: Gaussian (5/20)
# Optimization started
# Processing epoch	200	0.0271
# Training time: 17.99s, epochs: 200
#
# Least training loss reached: 0.027
# Dataset:  Gaussian
# -----------------------------
# KMeans:  0.6435277436707083 0.09856924495839288 0.984032 -0.9920000000000003
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6435277436707083 0.09856924495839288 0.984032 -0.9920000000000003
# DSC:  0.6322244592909906 0.035883894704233366 0.929154044581963 -0.9640694154969635
# -----------------------------
# Processing dataset: GaussianMix (5/20)
# Optimization started
# Processing epoch	200	0.0105
# Training time: 21.95s, epochs: 200
#
# Least training loss reached: 0.010
# Dataset:  GaussianMix
# -----------------------------
# KMeans:  0.6841696612519849 0.10389054380912274 1.0 0.5
# DBSCAN:  0.6048572335715502 0.20904348659001887 0.5706093189964158 0.0
# Agglomerative:  0.6841696612519849 0.10389054380912274 1.0 0.5
# DSC:  0.6816804797318925 0.0654664827632236 0.9850626884924543 0.4931178116115411
# -----------------------------
# Processing dataset: Atom (6/20)
# Optimization started
# Processing epoch	200	0.0410
# Training time: 29.47s, epochs: 200
#
# Least training loss reached: 0.041
# Dataset:  Atom
# -----------------------------
# KMeans:  0.41762078590995527 0.03848845969442412 0.18206807775637826 0.5214020477419581
# DBSCAN:  0 0 0 0
# Agglomerative:  0.41073709133177916 0.08623451728951541 0.09862621818643041 -0.4323697725073315
# DSC:  0.4136409972773324 0.040079469474647786 0.15932661957011873 0.49999999999999994
# -----------------------------
# Processing dataset: Chainlink (6/20)
# Optimization started
# Processing epoch	200	0.0324
# Training time: 37.48s, epochs: 200
#
# Least training loss reached: 0.032
# Dataset:  Chainlink
# -----------------------------
# KMeans:  0.3576634859293782 0.011819464263069736 0.10022375900972008 -0.3180769839462999
# DBSCAN:  0.16665067817267834 0.37189737642279397 1.0 1.0
# Agglomerative:  0.3399813559048249 0.03920914359049763 0.35706442581215536 -0.6530953403124256
# DSC:  0.3572088830888027 0.018168506721606987 0.09150661175941303 -0.30400243202918437
# -----------------------------
# Processing dataset: EngyTime (6/20)
# Optimization started
# Processing epoch	200	0.0472
# Training time: 142.69s, epochs: 200
#
# Least training loss reached: 0.047
# Dataset:  EngyTime
# -----------------------------
# KMeans:  0.42458379265139157 0.0017536764885264526 0.815060637690859 -0.9040667693054494
# DBSCAN:  0.4511335999702433 0.022944704031592777 -1.8752208275137675e-06 0.012795300381519263
# Agglomerative:  0.39934679304255377 0.004629677576555305 0.7184533725930805 0.8539403328927153
# DSC:  0.4139419071080529 0.003372573133298274 0.7604481583273094 -0.8722716465975897
# -----------------------------
# Processing dataset: Hepta (6/20)
# Optimization started
# Processing epoch	76	0.0326
# Training time: 2.77s, epochs: 76
#
# Least training loss reached: 0.038
# Dataset:  Hepta
# -----------------------------
# KMeans:  0.7019231989948803 1.065010037278373 1.0 -0.7551963048498846
# DBSCAN:  0.1075426321041714 0.027838598703172145 0.31328213511722036 0.2978287037296722
# Agglomerative:  0.7019231989948803 1.065010037278373 1.0 -0.6502804354998348
# DSC:  0.7019231989948803 1.065010037278373 1.0 -0.7551963048498846
# -----------------------------
# Processing dataset: Tetra (6/20)
# Optimization started
# Processing epoch	170	0.0099
# Training time: 12.04s, epochs: 170
#
# Least training loss reached: 0.010
# Dataset:  Tetra
# -----------------------------
# KMeans:  0.5057889289788572 0.22286832447315746 1.0 -0.7999999999999997
# DBSCAN:  0 0 0 0
# Agglomerative:  0.4952113887827159 0.1433076002637819 0.9672676330087653 0.015008444625821404
# DSC:  0.5020330024147078 0.08081231954814541 0.9866666397310955 -0.7956007679353988
# -----------------------------
# Processing dataset: Target (6/20)
# Optimization started
# Processing epoch	169	0.0169
# Training time: 23.34s, epochs: 169
#
# Least training loss reached: 0.017
# Dataset:  Target
# -----------------------------
# KMeans:  0.5825904772537839 0.02344538105942218 0.6355486669217713 0.541720278414311
# DBSCAN:  0.27620474177731674 0.11689895855783064 0.999634881516244 0.526597696226726
# Agglomerative:  0.5683249608036377 0.044301181765109374 0.6387791202472747 -0.6144108628824496
# DSC:  0.5590435949184654 0.016787864689482256 0.6361570665208345 0.5897137370567215
# -----------------------------
# Processing dataset: TwoDiamonds (6/20)
# Optimization started
# Processing epoch	200	0.0220
# Training time: 28.22s, epochs: 200
#
# Least training loss reached: 0.022
# Dataset:  TwoDiamonds
# -----------------------------
# KMeans:  0.6305972114000131 0.04499999999999993 1.0 -0.9999999999999998
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6305972114000131 0.04499999999999993 1.0 -0.9999999999999998
# DSC:  0.6305972114000131 0.04499999999999993 1.0 -0.9999999999999998
# -----------------------------
# Processing dataset: WingNut (6/20)
# Optimization started
# Processing epoch	200	0.0446
# Training time: 35.67s, epochs: 200
#
# Least training loss reached: 0.044
# Dataset:  WingNut
# -----------------------------
# KMeans:  0.460240362836918 0.01984498237527709 0.859497168372491 0.9271671507223962
# DBSCAN:  0 0 0 0
# Agglomerative:  0.43491039594216246 0.03016708956447158 0.6011477451948987 -0.7755905511811023
# DSC:  0.4482302192929621 0.08320502943378437 1.0 1.0
# -----------------------------
# Processing dataset: Iris (6/20)
# Optimization started
# Processing epoch	200	0.0227
# Training time: 5.09s, epochs: 200
#
# Least training loss reached: 0.023
# Dataset:  Iris
# -----------------------------
# KMeans:  0.5511916046195919 0.10943513103291669 0.7163421126838476 0.6096805124846351
# DBSCAN:  0.48603419703456857 0.07543555587646832 0.5206185241703302 0.36771246459370666
# Agglomerative:  0.5543236611296419 0.1127947086987354 0.7311985567707746 0.20544090417863603
# DSC:  0.5481277835097936 0.10088665446106332 0.7445264308738749 0.6050854150069594
# -----------------------------
# Processing dataset: Wine (6/20)
# Optimization started
# Processing epoch	200	0.0435
# Training time: 6.27s, epochs: 200
#
# Least training loss reached: 0.043
# Dataset:  Wine
# -----------------------------
# KMeans:  0.5595823478987213 0.014749468689460535 0.3517721516862617 -0.49436379276374254
# DBSCAN:  0 0 0 0
# Agglomerative:  0.5644796401732068 0.022374511405772082 0.36840191587483156 0.5725250629992938
# DSC:  0.4912009527614112 0.004699434013830241 0.3606673704170406 -0.5763446280657629
# -----------------------------
# Processing dataset: Uniform (6/20)
# Optimization started
# Processing epoch	200	0.0343
# Training time: 17.01s, epochs: 200
#
# Least training loss reached: 0.034
# Dataset:  Uniform
# -----------------------------
# KMeans:  0.6092631731974764 0.0076467486244800025 0.9681923665792226 -0.9841108417256753
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6008471293304483 0.014950812622520028 0.6265259590119457 -0.8079466429027214
# DSC:  0.6092812517586981 0.011087505148872884 0.9603206157858745 -0.9801803569660551
# -----------------------------
# Processing dataset: Rectangle (6/20)
# Optimization started
# Processing epoch	200	0.0336
# Training time: 44.76s, epochs: 200
#
# Least training loss reached: 0.033
# Dataset:  Rectangle
# -----------------------------
# KMeans:  0.439638954527144 0.1482489233833969 1.0 -1.0
# DBSCAN:  0 0 0 0
# Agglomerative:  0.439638954527144 0.1482489233833969 1.0 1.0
# DSC:  0.439638954527144 0.1482489233833969 1.0 -1.0
# -----------------------------
# Processing dataset: Gaussian (6/20)
# Optimization started
# Processing epoch	200	0.0271
# Training time: 17.12s, epochs: 200
#
# Least training loss reached: 0.027
# Dataset:  Gaussian
# -----------------------------
# KMeans:  0.6435277436707083 0.09856924495839288 0.984032 0.9920000000000003
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6435277436707083 0.09856924495839288 0.984032 -0.9920000000000003
# DSC:  0.6322244592909906 0.035883894704233366 0.929154044581963 0.9640694154969635
# -----------------------------
# Processing dataset: GaussianMix (6/20)
# Optimization started
# Processing epoch	200	0.0117
# Training time: 22.19s, epochs: 200
#
# Least training loss reached: 0.012
# Dataset:  GaussianMix
# -----------------------------
# KMeans:  0.6841696612519849 0.10389054380912274 1.0 -0.5
# DBSCAN:  0.6048572335715502 0.20904348659001887 0.5706093189964158 0.0
# Agglomerative:  0.6841696612519849 0.10389054380912274 1.0 0.5
# DSC:  0.6816804797318925 0.0654664827632236 0.9850626884924543 -0.49188654910652435
# -----------------------------
# Processing dataset: Atom (7/20)
# Optimization started
# Processing epoch	200	0.0287
# Training time: 29.08s, epochs: 200
#
# Least training loss reached: 0.028
# Dataset:  Atom
# -----------------------------
# KMeans:  0.4174271440008239 0.03231027991438114 0.1929066472123236 -0.5310850045437943
# DBSCAN:  0 0 0 0
# Agglomerative:  0.41073709133177916 0.08623451728951541 0.09862621818643041 -0.4323697725073315
# DSC:  0.4136409972773324 0.040079469474647786 0.15932661957011873 -0.49999999999999994
# -----------------------------
# Processing dataset: Chainlink (7/20)
# Optimization started
# Processing epoch	200	0.0296
# Training time: 36.80s, epochs: 200
#
# Least training loss reached: 0.029
# Dataset:  Chainlink
# -----------------------------
# KMeans:  0.35730946464884406 0.018168506721606987 0.09272782327563998 0.306000612001836
# DBSCAN:  0.16665067817267834 0.37189737642279397 1.0 1.0
# Agglomerative:  0.3399813559048249 0.03920914359049763 0.35706442581215536 -0.6530953403124256
# DSC:  0.3572088830888027 0.018168506721606987 0.09150661175941303 0.30400243202918437
# -----------------------------
# Processing dataset: EngyTime (7/20)
# Optimization started
# Processing epoch	200	0.0440
# Training time: 142.28s, epochs: 200
#
# Least training loss reached: 0.044
# Dataset:  EngyTime
# -----------------------------
# KMeans:  0.42458379265139157 0.0017536764885264526 0.815060637690859 -0.9040667693054494
# DBSCAN:  0.4511335999702433 0.022944704031592777 -1.8752208275137675e-06 0.012795300381519263
# Agglomerative:  0.39934679304255377 0.004629677576555305 0.7184533725930805 0.8539403328927153
# DSC:  0.4139419071080529 0.003372573133298274 0.7604481583273094 -0.8722716465975897
# -----------------------------
# Processing dataset: Hepta (7/20)
# Optimization started
# Processing epoch	76	0.0331
# Training time: 2.96s, epochs: 76
#
# Least training loss reached: 0.038
# Dataset:  Hepta
# -----------------------------
# KMeans:  0.7019231989948803 1.065010037278373 1.0 0.7202243483998682
# DBSCAN:  0.1075426321041714 0.027838598703172145 0.31328213511722036 0.2978287037296722
# Agglomerative:  0.7019231989948803 1.065010037278373 1.0 -0.6502804354998348
# DSC:  0.7019231989948803 1.065010037278373 1.0 0.7202243483998682
# -----------------------------
# Processing dataset: Tetra (7/20)
# Optimization started
# Processing epoch	149	0.0122
# Training time: 10.85s, epochs: 149
#
# Least training loss reached: 0.012
# Dataset:  Tetra
# -----------------------------
# KMeans:  0.5057889289788572 0.22286832447315746 1.0 -0.7999999999999997
# DBSCAN:  0 0 0 0
# Agglomerative:  0.4952113887827159 0.1433076002637819 0.9672676330087653 0.015008444625821404
# DSC:  0.4915647724834497 0.06492093768997717 0.9604834847820484 -0.7980667438613168
# -----------------------------
# Processing dataset: Target (7/20)
# Optimization started
# Processing epoch	142	0.0277
# Training time: 20.16s, epochs: 142
#
# Least training loss reached: 0.028
# Dataset:  Target
# -----------------------------
# KMeans:  0.37813212087350767 0.007078241199660155 0.3846045385526558 0.03798672976446046
# DBSCAN:  0.27620474177731674 0.11689895855783064 0.999634881516244 0.526597696226726
# Agglomerative:  0.5683249608036377 0.044301181765109374 0.6387791202472747 -0.6144108628824496
# DSC:  0.36062051049564664 0.005435779777229921 0.3881531834659593 0.017558701866972337
# -----------------------------
# Processing dataset: TwoDiamonds (7/20)
# Optimization started
# Processing epoch	200	0.0262
# Training time: 28.93s, epochs: 200
#
# Least training loss reached: 0.026
# Dataset:  TwoDiamonds
# -----------------------------
# KMeans:  0.6305972114000131 0.04499999999999993 1.0 -0.9999999999999998
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6305972114000131 0.04499999999999993 1.0 -0.9999999999999998
# DSC:  0.6305972114000131 0.04499999999999993 1.0 -0.9999999999999998
# -----------------------------
# Processing dataset: WingNut (7/20)
# Optimization started
# Processing epoch	200	0.0438
# Training time: 36.19s, epochs: 200
#
# Least training loss reached: 0.044
# Dataset:  WingNut
# -----------------------------
# KMeans:  0.460240362836918 0.01984498237527709 0.859497168372491 0.9271671507223962
# DBSCAN:  0 0 0 0
# Agglomerative:  0.43491039594216246 0.03016708956447158 0.6011477451948987 -0.7755905511811023
# ...
# Processing epoch	200	0.0269
# Training time: 44.50s, epochs: 200
#
# Least training loss reached: 0.027
# Dataset:  Rectangle
# -----------------------------
# KMeans:  0.439638954527144 0.1482489233833969 1.0 -1.0
# DBSCAN:  0 0 0 0
# Agglomerative:  0.439638954527144 0.1482489233833969 1.0 1.0
# DSC:  0.439638954527144 0.1482489233833969 1.0 -1.0
# -----------------------------
# Processing dataset: Gaussian (18/20)
# Optimization started
# Processing epoch	200	0.0305
# Training time: 16.89s, epochs: 200
#
# Least training loss reached: 0.030
# Dataset:  Gaussian
# -----------------------------
# KMeans:  0.6435277436707083 0.09856924495839288 0.984032 -0.9920000000000003
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6435277436707083 0.09856924495839288 0.984032 -0.9920000000000003
# DSC:  0.6415734519506503 0.0445832282181824 0.968192261115854 -0.9840314895115045
# -----------------------------
# Processing dataset: GaussianMix (18/20)
# Optimization started
# Processing epoch	200	0.0119
# Training time: 21.13s, epochs: 200
#
# Least training loss reached: 0.012
# Dataset:  GaussianMix
# -----------------------------
# KMeans:  0.6841696612519849 0.10389054380912274 1.0 -1.0
# DBSCAN:  0.6048572335715502 0.20904348659001887 0.5706093189964158 0.0
# Agglomerative:  0.6841696612519849 0.10389054380912274 1.0 0.5
# DSC:  0.6816804797318925 0.0654664827632236 0.9850626884924543 -0.9850082084359391
# -----------------------------
# Processing dataset: Atom (19/20)
# Optimization started
# Processing epoch	200	0.0316
# Training time: 28.44s, epochs: 200
#
# Least training loss reached: 0.031
# Dataset:  Atom
# -----------------------------
# KMeans:  0.42206675649084574 0.02943757230277807 0.14564469269222696 0.48628802501877577
# DBSCAN:  0 0 0 0
# Agglomerative:  0.41073709133177916 0.08623451728951541 0.09862621818643041 -0.4323697725073315
# DSC:  0.42112349590542136 0.0424033296098608 0.13440630315586855 0.47446270087079656
# -----------------------------
# Processing dataset: Chainlink (19/20)
# Optimization started
# Processing epoch	200	0.0315
# Training time: 35.46s, epochs: 200
#
# Least training loss reached: 0.031
# Dataset:  Chainlink
# -----------------------------
# KMeans:  0.357243191543669 0.010060645216962906 0.09029341558059824 0.30200543614677633
# DBSCAN:  0.16665067817267834 0.37189737642279397 1.0 1.0
# Agglomerative:  0.3399813559048249 0.03920914359049763 0.35706442581215536 -0.6530953403124256
# DSC:  0.3572088830888027 0.018168506721606987 0.09150661175941303 0.30400243202918437
# -----------------------------
# Processing dataset: EngyTime (19/20)
# Optimization started
# Processing epoch	200	0.0450
# Training time: 137.89s, epochs: 200
#
# Least training loss reached: 0.045
# Dataset:  EngyTime
# -----------------------------
# KMeans:  0.42458379265139157 0.0017536764885264526 0.815060637690859 0.9040667693054494
# DBSCAN:  0.4511335999702433 0.022944704031592777 -1.8752208275137675e-06 0.012795300381519263
# Agglomerative:  0.39934679304255377 0.004629677576555305 0.7184533725930805 0.8539403328927153
# DSC:  0.4139419071080529 0.003372573133298274 0.7604481583273094 0.8722716465975897
# -----------------------------
# Processing dataset: Hepta (19/20)
# Optimization started
# Processing epoch	76	0.0335
# Training time: 2.69s, epochs: 76
#
# Least training loss reached: 0.039
# Dataset:  Hepta
# -----------------------------
# KMeans:  0.7019231989948803 1.065010037278373 1.0 0.5453645661497852
# DBSCAN:  0.1075426321041714 0.027838598703172145 0.31328213511722036 0.2978287037296722
# Agglomerative:  0.7019231989948803 1.065010037278373 1.0 -0.6502804354998348
# DSC:  0.7019231989948803 1.065010037278373 1.0 0.5453645661497852
# -----------------------------
# Processing dataset: Tetra (19/20)
# Optimization started
# Processing epoch	176	0.0091
# Training time: 12.07s, epochs: 176
#
# Least training loss reached: 0.009
# Dataset:  Tetra
# -----------------------------
# KMeans:  0.5057889289788572 0.22286832447315746 1.0 -0.9999999999999996
# DBSCAN:  0 0 0 0
# Agglomerative:  0.4952113887827159 0.1433076002637819 0.9672676330087653 0.015008444625821404
# DSC:  0.5020330024147078 0.08081231954814541 0.9866666397310955 -0.995002487509328
# -----------------------------
# Processing dataset: Target (19/20)
# Optimization started
# Processing epoch	166	0.0191
# Training time: 22.44s, epochs: 166
#
# Least training loss reached: 0.019
# Dataset:  Target
# -----------------------------
# KMeans:  0.5811169728017377 0.01440673155409106 0.6355633954868499 -0.1951071102235264
# DBSCAN:  0.27620474177731674 0.11689895855783064 0.999634881516244 0.526597696226726
# Agglomerative:  0.5683249608036377 0.044301181765109374 0.6387791202472747 -0.6144108628824496
# DSC:  0.5463850809638403 0.018198976309978108 0.6384784573034711 -0.14185018234882057
# -----------------------------
# Processing dataset: TwoDiamonds (19/20)
# Optimization started
# Processing epoch	200	0.0205
# Training time: 27.94s, epochs: 200
#
# Least training loss reached: 0.020
# Dataset:  TwoDiamonds
# -----------------------------
# KMeans:  0.6305972114000131 0.04499999999999993 1.0 -0.9999999999999998
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6305972114000131 0.04499999999999993 1.0 -0.9999999999999998
# DSC:  0.6305972114000131 0.04499999999999993 1.0 -0.9999999999999998
# -----------------------------
# Processing dataset: WingNut (19/20)
# Optimization started
# Processing epoch	200	0.0444
# Training time: 35.95s, epochs: 200
#
# Least training loss reached: 0.044
# Dataset:  WingNut
# -----------------------------
# KMeans:  0.4602403628385199 0.01984498237527709 0.859497168372491 -0.9271671507223962
# DBSCAN:  0 0 0 0
# Agglomerative:  0.43491039594216246 0.03016708956447158 0.6011477451948987 -0.7755905511811023
# DSC:  0.4482302192929621 0.08320502943378437 1.0 -1.0
# -----------------------------
# Processing dataset: Iris (19/20)
# Optimization started
# Processing epoch	200	0.0222
# Training time: 5.06s, epochs: 200
#
# Least training loss reached: 0.022
# Dataset:  Iris
# -----------------------------
# KMeans:  0.5511916046195919 0.10943513103291669 0.7163421126838476 0.6096805124846351
# DBSCAN:  0.48603419703456857 0.07543555587646832 0.5206185241703302 0.36771246459370666
# Agglomerative:  0.5543236611296419 0.1127947086987354 0.7311985567707746 0.20544090417863603
# DSC:  0.5481277835097936 0.10088665446106332 0.7445264308738749 0.6050854150069594
# -----------------------------
# Processing dataset: Wine (19/20)
# Optimization started
# Processing epoch	200	0.0314
# Training time: 6.63s, epochs: 200
#
# Least training loss reached: 0.031
# Dataset:  Wine
# -----------------------------
# KMeans:  0.5711381937868838 0.01626043915542385 0.37111371823084754 0.5879609988452332
# DBSCAN:  0 0 0 0
# Agglomerative:  0.5644796401732068 0.022374511405772082 0.36840191587483156 0.5725250629992938
# DSC:  0.5440687651544346 0.006738631513339247 0.3835442596929009 0.6108348027755139
# -----------------------------
# Processing dataset: Uniform (19/20)
# Optimization started
# Processing epoch	200	0.0252
# Training time: 17.01s, epochs: 200
#
# Least training loss reached: 0.025
# Dataset:  Uniform
# -----------------------------
# KMeans:  0.6092631731974764 0.0076467486244800025 0.9681923665792226 -0.9841108417256753
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6008471293304483 0.014950812622520028 0.6265259590119457 -0.8079466429027214
# DSC:  0.6092812517586981 0.011087505148872884 0.9603206157858745 -0.9801803569660551
# -----------------------------
# Processing dataset: Rectangle (19/20)
# Optimization started
# Processing epoch	200	0.0258
# Training time: 45.01s, epochs: 200
#
# Least training loss reached: 0.025
# Dataset:  Rectangle
# -----------------------------
# KMeans:  0.439638954527144 0.1482489233833969 1.0 -1.0
# DBSCAN:  0 0 0 0
# Agglomerative:  0.439638954527144 0.1482489233833969 1.0 1.0
# DSC:  0.439638954527144 0.1482489233833969 1.0 -1.0
# -----------------------------
# Processing dataset: Gaussian (19/20)
# Optimization started
# Processing epoch	200	0.0291
# Training time: 16.95s, epochs: 200
#
# Least training loss reached: 0.029
# Dataset:  Gaussian
# -----------------------------
# KMeans:  0.6435277436707083 0.09856924495839288 0.984032 0.9920000000000003
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6435277436707083 0.09856924495839288 0.984032 -0.9920000000000003
# DSC:  0.6415734519506503 0.0445832282181824 0.968192261115854 0.9840314895115045
# -----------------------------
# Processing dataset: GaussianMix (19/20)
# Optimization started
# Processing epoch	200	0.0116
# Training time: 20.90s, epochs: 200
#
# Least training loss reached: 0.011
# Dataset:  GaussianMix
# -----------------------------
# KMeans:  0.6841696612519849 0.10389054380912274 1.0 -0.5
# DBSCAN:  0.6048572335715502 0.20904348659001887 0.5706093189964158 0.0
# Agglomerative:  0.6841696612519849 0.10389054380912274 1.0 0.5
# DSC:  0.6816804797318925 0.0654664827632236 0.9850626884924543 -0.49188654910652435
# -----------------------------
# Processing dataset: Atom (20/20)
# Optimization started
# Processing epoch	200	0.0460
# Training time: 27.92s, epochs: 200
#
# Least training loss reached: 0.046
# Dataset:  Atom
# -----------------------------
# KMeans:  0.4176929456784954 0.02327702996787836 0.1885336032086663 0.5272146351966105
# DBSCAN:  0 0 0 0
# Agglomerative:  0.41073709133177916 0.08623451728951541 0.09862621818643041 -0.4323697725073315
# DSC:  0.4136409972773324 0.040079469474647786 0.15932661957011873 0.49999999999999994
# -----------------------------
# Processing dataset: Chainlink (20/20)
# Optimization started
# Processing epoch	200	0.0373
# Training time: 35.39s, epochs: 200
#
# Least training loss reached: 0.037
# Dataset:  Chainlink
# -----------------------------
# KMeans:  0.35778822862903487 0.010060645216962906 0.10022341280326524 0.31801590119259937
# DBSCAN:  0.16665067817267834 0.37189737642279397 1.0 1.0
# Agglomerative:  0.3399813559048249 0.03920914359049763 0.35706442581215536 -0.6530953403124256
# DSC:  0.3572088830888027 0.018168506721606987 0.09150661175941303 0.30400243202918437
# -----------------------------
# Processing dataset: EngyTime (20/20)
# Optimization started
# Processing epoch	200	0.0477
# Training time: 137.36s, epochs: 200
#
# Least training loss reached: 0.047
# Dataset:  EngyTime
# -----------------------------
# KMeans:  0.42458379265139157 0.0017536764885264526 0.815060637690859 -0.9040667693054494
# DBSCAN:  0.4511335999702433 0.022944704031592777 -1.8752208275137675e-06 0.012795300381519263
# Agglomerative:  0.39934679304255377 0.004629677576555305 0.7184533725930805 0.8539403328927153
# DSC:  0.4139419071080529 0.003372573133298274 0.7604481583273094 -0.8722716465975897
# -----------------------------
# Processing dataset: Hepta (20/20)
# Optimization started
# Processing epoch	76	0.0342
# Training time: 2.83s, epochs: 76
#
# Least training loss reached: 0.039
# Dataset:  Hepta
# -----------------------------
# KMeans:  0.7019231989948803 1.065010037278373 1.0 0.21204703253562412
# DBSCAN:  0.1075426321041714 0.027838598703172145 0.31328213511722036 0.2978287037296722
# Agglomerative:  0.7019231989948803 1.065010037278373 1.0 -0.6502804354998348
# DSC:  0.7019231989948803 1.065010037278373 1.0 0.21204703253562412
# -----------------------------
# Processing dataset: Tetra (20/20)
# Optimization started
# Processing epoch	194	0.0072
# Training time: 13.20s, epochs: 194
#
# Least training loss reached: 0.007
# Dataset:  Tetra
# -----------------------------
# KMeans:  0.5057889289788572 0.22286832447315746 1.0 0.3999999999999998
# DBSCAN:  0 0 0 0
# Agglomerative:  0.4952113887827159 0.1433076002637819 0.9672676330087653 0.015008444625821404
# DSC:  0.5020330024147078 0.08081231954814541 0.9866666397310955 0.40618944531754864
# -----------------------------
# Processing dataset: Target (20/20)
# Optimization started
# Processing epoch	171	0.0100
# Training time: 23.15s, epochs: 171
#
# Least training loss reached: 0.010
# Dataset:  Target
# -----------------------------
# KMeans:  0.5779221485341608 0.01674723542126409 0.636418714175416 0.7238657165385847
# DBSCAN:  0.27620474177731674 0.11689895855783064 0.999634881516244 0.526597696226726
# Agglomerative:  0.5683249608036377 0.044301181765109374 0.6387791202472747 -0.6144108628824496
# DSC:  0.5684264736595016 0.017875144132636186 0.6386565741208261 0.7199722755255995
# -----------------------------
# Processing dataset: TwoDiamonds (20/20)
# Optimization started
# Processing epoch	200	0.0256
# Training time: 27.83s, epochs: 200
#
# Least training loss reached: 0.025
# Dataset:  TwoDiamonds
# -----------------------------
# KMeans:  0.6305972114000131 0.04499999999999993 1.0 -0.9999999999999998
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6305972114000131 0.04499999999999993 1.0 -0.9999999999999998
# DSC:  0.6305972114000131 0.04499999999999993 1.0 -0.9999999999999998
# -----------------------------
# Processing dataset: WingNut (20/20)
# Optimization started
# Processing epoch	200	0.0497
# Training time: 35.92s, epochs: 200
#
# Least training loss reached: 0.049
# Dataset:  WingNut
# -----------------------------
# KMeans:  0.4602403628385199 0.01984498237527709 0.859497168372491 -0.9271671507223962
# DBSCAN:  0 0 0 0
# Agglomerative:  0.43491039594216246 0.03016708956447158 0.6011477451948987 -0.7755905511811023
# DSC:  0.4482302192929621 0.08320502943378437 1.0 -1.0
# -----------------------------
# Processing dataset: Iris (20/20)
# Optimization started
# Processing epoch	200	0.0217
# Training time: 5.19s, epochs: 200
#
# Least training loss reached: 0.022
# Dataset:  Iris
# -----------------------------
# KMeans:  0.5511916046195919 0.10943513103291669 0.7163421126838476 -0.2236376039494433
# DBSCAN:  0.48603419703456857 0.07543555587646832 0.5206185241703302 0.36771246459370666
# Agglomerative:  0.5543236611296419 0.1127947086987354 0.7311985567707746 0.20544090417863603
# DSC:  0.5481277835097936 0.10088665446106332 0.7445264308738749 -0.22513144257068346
# -----------------------------
# Processing dataset: Wine (20/20)
# Optimization started
# Processing epoch	200	0.0424
# Training time: 6.67s, epochs: 200
#
# Least training loss reached: 0.042
# Dataset:  Wine
# -----------------------------
# KMeans:  0.5595823478987213 0.014749468689460535 0.3517721516862617 -0.09470645748887452
# DBSCAN:  0 0 0 0
# Agglomerative:  0.5644796401732068 0.022374511405772082 0.36840191587483156 0.5725250629992938
# DSC:  0.5076913477719204 0.008545830157896025 0.35969275134598705 -0.04760769436936062
# -----------------------------
# Processing dataset: Uniform (20/20)
# Optimization started
# Processing epoch	200	0.0264
# Training time: 17.39s, epochs: 200
#
# Least training loss reached: 0.026
# Dataset:  Uniform
# -----------------------------
# KMeans:  0.6092631731974764 0.0076467486244800025 0.9681923665792226 -0.9841108417256753
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6008471293304483 0.014950812622520028 0.6265259590119457 -0.8079466429027214
# DSC:  0.6092812517586981 0.011087505148872884 0.9603206157858745 -0.9801803569660551
# -----------------------------
# Processing dataset: Rectangle (20/20)
# Optimization started
# Processing epoch	200	0.0285
# Training time: 45.42s, epochs: 200
#
# Least training loss reached: 0.028
# Dataset:  Rectangle
# -----------------------------
# KMeans:  0.439638954527144 0.1482489233833969 1.0 1.0
# DBSCAN:  0 0 0 0
# Agglomerative:  0.439638954527144 0.1482489233833969 1.0 1.0
# DSC:  0.439638954527144 0.1482489233833969 1.0 1.0
# -----------------------------
# Processing dataset: Gaussian (20/20)
# Optimization started
# Processing epoch	200	0.0301
# Training time: 17.31s, epochs: 200
#
# Least training loss reached: 0.030
# Dataset:  Gaussian
# -----------------------------
# KMeans:  0.6435277436707083 0.09856924495839288 0.984032 0.9920000000000003
# DBSCAN:  0 0 0 0
# Agglomerative:  0.6435277436707083 0.09856924495839288 0.984032 -0.9920000000000003
# DSC:  0.6228243739102449 0.012432576744397522 0.8909174116090074 0.9440302094500612
# -----------------------------
# Processing dataset: GaussianMix (20/20)
# Optimization started
# Processing epoch	200	0.0114
# Training time: 20.92s, epochs: 200
#
# Least training loss reached: 0.011
# Dataset:  GaussianMix
# -----------------------------
# KMeans:  0.6841696612519849 0.10389054380912274 1.0 0.5
# DBSCAN:  0.6048572335715502 0.20904348659001887 0.5706093189964158 0.0
# Agglomerative:  0.6841696612519849 0.10389054380912274 1.0 0.5
# DSC:  0.6816804797318925 0.0654664827632236 0.9850626884924543 0.4931178116115411
# -----------------------------

# %%
#evaluamos los resultados
for i in range(20):
    results = pd.read_csv('results/results'+str(i)+'.csv')
    for dataset in results['Dataset'].unique():
        dataset_results = results[results['Dataset'] == dataset]
        print("Dataset: ", dataset)
        print("-----------------------------")
        print(dataset_results)
        print("-----------------------------")
# Out:
# Dataset:  Atom
# -----------------------------
#   Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 0    Atom                            KMeans    0.389760  0.051867  0.149491
# 1    Atom                            DBSCAN    0.460870  0.018507  0.567669
# 2    Atom                     Agglomerative    0.383773  0.068420  0.067072
# 3    Atom                  CDSDG Clustering    0.453309  0.036231  0.487792
# 4    Atom                      CDSDG Voting    0.453309  0.036231  0.487792
# 5    Atom  CDSDG Clustering with n_clusters    0.388044  0.027397  0.171543
#
#     Pearson
# 0 -0.490214
# 1  0.915116
# 2 -0.386556
# 3 -0.297969
# 4 -0.297969
# 5  0.511693
# -----------------------------
# Dataset:  Chainlink
# -----------------------------
#       Dataset                         Algorithm  Silhouette      Dunn  \
# 6   Chainlink                            KMeans    0.282240  0.017234
# 7   Chainlink                            DBSCAN    0.153636  0.220721
# 8   Chainlink                     Agglomerative    0.271943  0.018816
# 9   Chainlink                  CDSDG Clustering    0.434951  0.009197
# 10  Chainlink                      CDSDG Voting    0.434951  0.009197
# 11  Chainlink  CDSDG Clustering with n_clusters    0.247633  0.014690
#
#         Rand   Pearson
# 6   0.000155 -0.034001
# 7   1.000000  1.000000
# 8  -0.000902  0.008145
# 9   0.328304  0.426778
# 10  0.328304  0.426778
# 11  0.076371  0.279824
# -----------------------------
# Dataset:  EngyTime
# -----------------------------
#      Dataset                         Algorithm  Silhouette      Dunn  \
# 12  EngyTime                            KMeans    0.413282  0.004957
# 13  EngyTime                            DBSCAN    0.382455  0.035779
# 14  EngyTime                     Agglomerative    0.407908  0.003910
# 15  EngyTime                  CDSDG Clustering    0.414493  0.003058
# 16  EngyTime                      CDSDG Voting   -0.038151  0.002094
# 17  EngyTime  CDSDG Clustering with n_clusters    0.413367  0.000942
#
#         Rand   Pearson
# 12  0.812417 -0.904415
# 13  0.000001 -0.027073
# 14  0.808021  0.902778
# 15  0.501168  0.725163
# 16  0.051674  0.285632
# 17  0.814179  0.905323
# -----------------------------
# Dataset:  Hepta
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn  Rand  \
# 18   Hepta                            KMeans    0.702131  1.049754   1.0
# 19   Hepta                            DBSCAN    0.702131  1.049754   1.0
# 20   Hepta                     Agglomerative    0.702131  1.049754   1.0
# 21   Hepta                  CDSDG Clustering    0.702131  1.049754   1.0
# 22   Hepta                      CDSDG Voting    0.702131  1.049754   1.0
# 23   Hepta  CDSDG Clustering with n_clusters    0.702131  1.049754   1.0
#
#      Pearson
# 18  0.685252
# 19  1.000000
# 20 -0.440449
# 21  1.000000
# 22  1.000000
# 23  0.112892
# -----------------------------
# Dataset:  Tetra
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 24   Tetra                            KMeans    0.505794  0.223787  1.000000
# 25   Tetra                            DBSCAN    0.306610  0.101004  0.687028
# 26   Tetra                     Agglomerative    0.495199  0.142927  0.967268
# 27   Tetra                  CDSDG Clustering    0.492771  0.042320  0.966658
# 28   Tetra                      CDSDG Voting    0.489435  0.046814  0.960308
# 29   Tetra  CDSDG Clustering with n_clusters    0.492771  0.042320  0.966658
#
#      Pearson
# 24 -0.800000
# 25  0.839066
# 26  0.015008
# 27 -0.008965
# 28 -0.010002
# 29 -0.008965
# -----------------------------
# Dataset:  Target
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 30  Target                            KMeans    0.578341  0.013718  0.636675
# 31  Target                            DBSCAN    0.276200  0.116434  0.999635
# 32  Target                     Agglomerative    0.568308  0.044261  0.638779
# 33  Target                  CDSDG Clustering    0.550941  0.261923  0.029222
# 34  Target                      CDSDG Voting    0.342860  0.007502  0.059634
# 35  Target  CDSDG Clustering with n_clusters    0.580701  0.015461  0.635136
#
#      Pearson
# 30  0.725546
# 31  0.526598
# 32 -0.614411
# 33  0.414655
# 34  0.316822
# 35  0.723725
# -----------------------------
# Dataset:  TwoDiamonds
# -----------------------------
#         Dataset                         Algorithm  Silhouette      Dunn  \
# 36  TwoDiamonds                            KMeans    0.424732  0.017352
# 37  TwoDiamonds                            DBSCAN    0.000000  0.000000
# 38  TwoDiamonds                     Agglomerative    0.424732  0.017352
# 39  TwoDiamonds                  CDSDG Clustering    0.447150  0.015157
# 40  TwoDiamonds                      CDSDG Voting    0.447150  0.015157
# 41  TwoDiamonds  CDSDG Clustering with n_clusters    0.424732  0.017352
#
#         Rand   Pearson
# 36  1.000000  1.000000
# 37  0.000000  0.000000
# 38  1.000000  1.000000
# 39  0.502073  0.467668
# 40  0.502073  0.467668
# 41  1.000000  1.000000
# -----------------------------
# Dataset:  WingNut
# -----------------------------
#     Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 42  WingNut                            KMeans    0.437990  0.013645  0.679985
# 43  WingNut                            DBSCAN    0.000000  0.000000  0.000000
# 44  WingNut                     Agglomerative    0.411792  0.071475  1.000000
# 45  WingNut                  CDSDG Clustering    0.415174  0.013936  0.520898
# 46  WingNut                      CDSDG Voting    0.280264  0.010203  0.361223
# 47  WingNut  CDSDG Clustering with n_clusters    0.437988  0.015188  0.670268
#
#      Pearson
# 42 -0.824818
# 43  0.000000
# 44  1.000000
# 45  0.585621
# 46  0.468752
# 47  0.818898
# -----------------------------
# Dataset:  Iris
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 48    Iris                            KMeans    0.459948  0.026497  0.620135
# 49    Iris                            DBSCAN    0.356516  0.047926  0.442099
# 50    Iris                     Agglomerative    0.446689  0.098267  0.615323
# 51    Iris                  CDSDG Clustering    0.504646  0.239169  0.558371
# 52    Iris                      CDSDG Voting    0.292992  0.053693  0.536356
# 53    Iris  CDSDG Clustering with n_clusters    0.581750  0.267426  0.568116
#
#      Pearson
# 48 -0.220264
# 49  0.194046
# 50 -0.495993
# 51 -0.822466
# 52 -0.355202
# 53  0.866025
# -----------------------------
# Dataset:  Wine
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 54    Wine                            KMeans    0.285942  0.176897  0.914880
# 55    Wine                            DBSCAN    0.000000  0.000000  0.000000
# 56    Wine                     Agglomerative    0.277444  0.228586  0.789933
# 57    Wine                  CDSDG Clustering    0.214287  0.159888  0.751174
# 58    Wine                      CDSDG Voting    0.254870  0.159888  0.775998
# 59    Wine  CDSDG Clustering with n_clusters    0.277067  0.198965  0.866940
#
#      Pearson
# 54  0.510683
# 55  0.000000
# 56 -0.515213
# 57 -0.319591
# 58 -0.364364
# 59 -0.523791
# -----------------------------
# Dataset:  Uniform
# -----------------------------
#     Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 60  Uniform                            KMeans    0.609263  0.007647  0.968192
# 61  Uniform                            DBSCAN    0.000000  0.000000  0.000000
# 62  Uniform                     Agglomerative    0.600847  0.014951  0.626526
# 63  Uniform                  CDSDG Clustering    0.572247  0.002531  0.469504
# 64  Uniform                      CDSDG Voting    0.572247  0.002531  0.469504
# 65  Uniform  CDSDG Clustering with n_clusters    0.609263  0.007647  0.968192
#
#      Pearson
# 60 -0.984111
# 61  0.000000
# 62 -0.807947
# 63 -0.466066
# 64 -0.466066
# 65 -0.984111
# -----------------------------
# Dataset:  Rectangle
# -----------------------------
#       Dataset                         Algorithm  Silhouette      Dunn  \
# 66  Rectangle                            KMeans    0.365392  0.007238
# 67  Rectangle                            DBSCAN    0.000000  0.000000
# 68  Rectangle                     Agglomerative    0.418023  0.137653
# 69  Rectangle                  CDSDG Clustering    0.495956  0.011770
# 70  Rectangle                      CDSDG Voting    0.495956  0.011770
# 71  Rectangle  CDSDG Clustering with n_clusters    0.365729  0.006781
#
#         Rand   Pearson
# 66  0.015470  0.127914
# 67  0.000000  0.000000
# 68  1.000000 -1.000000
# 69  0.500717 -0.464496
# 70  0.500717 -0.464496
# 71  0.024053 -0.158262
# -----------------------------
# Dataset:  Gaussian
# -----------------------------
#      Dataset                         Algorithm  Silhouette      Dunn  \
# 72  Gaussian                            KMeans    0.631411  0.092602
# 73  Gaussian                            DBSCAN    0.214779  0.114269
# 74  Gaussian                     Agglomerative    0.631471  0.092602
# 75  Gaussian                  CDSDG Clustering    0.421386  0.029300
# 76  Gaussian                      CDSDG Voting   -0.012018  0.008639
# 77  Gaussian  CDSDG Clustering with n_clusters    0.631411  0.092602
#
#         Rand   Pearson
# 72  0.976096  0.988008
# 73  0.000000 -0.044766
# 74  0.984032 -0.992000
# 75  0.925401 -0.927571
# 76  0.196129 -0.293407
# 77  0.976096  0.988008
# -----------------------------
# Dataset:  GaussianMix
# -----------------------------
#         Dataset                         Algorithm  Silhouette      Dunn  \
# 78  GaussianMix                            KMeans    0.689410  0.105251
# 79  GaussianMix                            DBSCAN    0.547011  0.179191
# 80  GaussianMix                     Agglomerative    0.689410  0.105251
# 81  GaussianMix                  CDSDG Clustering    0.676803  0.055938
# 82  GaussianMix                      CDSDG Voting    0.676803  0.055938
# 83  GaussianMix  CDSDG Clustering with n_clusters    0.689410  0.105251
#
#         Rand       Pearson
# 78  1.000000  1.000000e+00
# 79  0.570609 -1.814847e-18
# 80  1.000000 -1.000000e+00
# 81  0.980134 -9.950238e-01
# 82  0.980134 -9.950238e-01
# 83  1.000000 -5.000000e-01
# -----------------------------
# Dataset:  Atom
# -----------------------------
#   Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 0    Atom                            KMeans    0.388552  0.034221  0.173623
# 1    Atom                            DBSCAN    0.460870  0.018507  0.567669
# 2    Atom                     Agglomerative    0.383773  0.068420  0.067072
# 3    Atom                  CDSDG Clustering    0.453309  0.036231  0.487792
# 4    Atom                      CDSDG Voting    0.453547  0.036231  0.482312
# 5    Atom  CDSDG Clustering with n_clusters    0.388044  0.027397  0.171543
#
#     Pearson
# 0  0.513637
# 1  0.915116
# 2 -0.386556
# 3 -0.297969
# 4 -0.295399
# 5  0.511693
# -----------------------------
# Dataset:  Chainlink
# -----------------------------
#       Dataset                         Algorithm  Silhouette      Dunn  \
# 6   Chainlink                            KMeans    0.262032  0.019791
# 7   Chainlink                            DBSCAN    0.153636  0.220721
# 8   Chainlink                     Agglomerative    0.271943  0.018816
# 9   Chainlink                  CDSDG Clustering    0.434951  0.009197
# 10  Chainlink                      CDSDG Voting    0.434951  0.009197
# 11  Chainlink  CDSDG Clustering with n_clusters    0.247633  0.014690
#
#         Rand   Pearson
# 6   0.193046  0.531085
# 7   1.000000  1.000000
# 8  -0.000902  0.008145
# 9   0.328304  0.426778
# 10  0.328304  0.426778
# 11  0.076371  0.279824
# -----------------------------
# Dataset:  EngyTime
# -----------------------------
#      Dataset                         Algorithm  Silhouette      Dunn  \
# 12  EngyTime                            KMeans    0.413282  0.004957
# 13  EngyTime                            DBSCAN    0.382455  0.035779
# 14  EngyTime                     Agglomerative    0.407908  0.003910
# 15  EngyTime                  CDSDG Clustering    0.414493  0.003058
# 16  EngyTime                      CDSDG Voting   -0.020075  0.002094
# 17  EngyTime  CDSDG Clustering with n_clusters    0.413367  0.000942
#
#         Rand   Pearson
# 12  0.812417  0.904415
# 13  0.000001 -0.027073
# 14  0.808021  0.902778
# 15  0.501168  0.725163
# 16  0.053267  0.303978
# 17  0.814179  0.905323
# -----------------------------
# Dataset:  Hepta
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn  Rand  \
# 18   Hepta                            KMeans    0.702131  1.049754   1.0
# 19   Hepta                            DBSCAN    0.702131  1.049754   1.0
# 20   Hepta                     Agglomerative    0.702131  1.049754   1.0
# 21   Hepta                  CDSDG Clustering    0.702131  1.049754   1.0
# 22   Hepta                      CDSDG Voting    0.702131  1.049754   1.0
# 23   Hepta  CDSDG Clustering with n_clusters    0.702131  1.049754   1.0
#
#      Pearson
# 18  0.119464
# 19  1.000000
# 20 -0.440449
# 21  1.000000
# 22  1.000000
# 23  0.112892
# -----------------------------
# Dataset:  Tetra
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 24   Tetra                            KMeans    0.505794  0.223787  1.000000
# 25   Tetra                            DBSCAN    0.306610  0.101004  0.687028
# 26   Tetra                     Agglomerative    0.495199  0.142927  0.967268
# 27   Tetra                  CDSDG Clustering    0.492771  0.042320  0.966658
# 28   Tetra                      CDSDG Voting    0.492771  0.042320  0.966658
# 29   Tetra  CDSDG Clustering with n_clusters    0.485359  0.042320  0.953698
#
#      Pearson
# 24  0.400000
# 25  0.839066
# 26  0.015008
# 27 -0.008965
# 28 -0.008965
# 29 -0.013004
# -----------------------------
# Dataset:  Target
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 30  Target                            KMeans    0.572527  0.024536  0.657154
# 31  Target                            DBSCAN    0.276200  0.116434  0.999635
# 32  Target                     Agglomerative    0.568308  0.044261  0.638779
# 33  Target                  CDSDG Clustering    0.550941  0.261923  0.029222
# 34  Target                      CDSDG Voting    0.336525  0.008522  0.056942
# 35  Target  CDSDG Clustering with n_clusters    0.580701  0.015461  0.635136
#
#      Pearson
# 30  0.511767
# 31  0.526598
# 32 -0.614411
# 33  0.414655
# 34  0.313043
# 35  0.723725
# -----------------------------
# Dataset:  TwoDiamonds
# -----------------------------
#         Dataset                         Algorithm  Silhouette      Dunn  \
# 36  TwoDiamonds                            KMeans    0.424732  0.017352
# 37  TwoDiamonds                            DBSCAN    0.000000  0.000000
# 38  TwoDiamonds                     Agglomerative    0.424732  0.017352
# 39  TwoDiamonds                  CDSDG Clustering    0.447150  0.015157
# 40  TwoDiamonds                      CDSDG Voting    0.447150  0.015157
# 41  TwoDiamonds  CDSDG Clustering with n_clusters    0.424732  0.017352
#
#         Rand   Pearson
# 36  1.000000 -1.000000
# 37  0.000000  0.000000
# 38  1.000000  1.000000
# 39  0.502073  0.467668
# 40  0.502073  0.467668
# 41  1.000000  1.000000
# -----------------------------
# Dataset:  WingNut
# -----------------------------
#     Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 42  WingNut                            KMeans    0.437988  0.015188  0.670268
# 43  WingNut                            DBSCAN    0.000000  0.000000  0.000000
# 44  WingNut                     Agglomerative    0.411792  0.071475  1.000000
# 45  WingNut                  CDSDG Clustering    0.415174  0.013936  0.520898
# 46  WingNut                      CDSDG Voting    0.280264  0.010203  0.361223
# 47  WingNut  CDSDG Clustering with n_clusters    0.437988  0.015188  0.670268
#
#      Pearson
# 42 -0.818898
# 43  0.000000
# 44  1.000000
# 45  0.585621
# 46  0.468752
# 47  0.818898
# -----------------------------
# Dataset:  Iris
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 48    Iris                            KMeans    0.463042  0.057119  0.592333
# 49    Iris                            DBSCAN    0.356516  0.047926  0.442099
# 50    Iris                     Agglomerative    0.446689  0.098267  0.615323
# 51    Iris                  CDSDG Clustering    0.504646  0.239169  0.558371
# 52    Iris                      CDSDG Voting    0.292992  0.053693  0.536356
# 53    Iris  CDSDG Clustering with n_clusters    0.581750  0.267426  0.568116
#
#      Pearson
# 48 -0.160774
# 49  0.194046
# 50 -0.495993
# 51 -0.822466
# 52 -0.355202
# 53  0.866025
# -----------------------------
# Dataset:  Wine
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 54    Wine                            KMeans    0.284859  0.232257  0.897495
# 55    Wine                            DBSCAN    0.000000  0.000000  0.000000
# 56    Wine                     Agglomerative    0.277444  0.228586  0.789933
# 57    Wine                  CDSDG Clustering    0.214287  0.159888  0.751174
# 58    Wine                      CDSDG Voting    0.243193  0.159888  0.783921
# 59    Wine  CDSDG Clustering with n_clusters    0.284617  0.232257  0.913358
#
#      Pearson
# 54  0.426458
# 55  0.000000
# 56 -0.515213
# 57 -0.319591
# 58 -0.365982
# 59 -0.508051
# -----------------------------
# Dataset:  Uniform
# -----------------------------
#     Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 60  Uniform                            KMeans    0.609070  0.004129  0.984032
# 61  Uniform                            DBSCAN    0.000000  0.000000  0.000000
# 62  Uniform                     Agglomerative    0.600847  0.014951  0.626526
# 63  Uniform                  CDSDG Clustering    0.572247  0.002531  0.469504
# 64  Uniform                      CDSDG Voting    0.572247  0.002531  0.469504
# 65  Uniform  CDSDG Clustering with n_clusters    0.609263  0.007647  0.968192
#
#      Pearson
# 60 -0.992022
# 61  0.000000
# 62 -0.807947
# 63 -0.466066
# 64 -0.466066
# 65 -0.984111
# -----------------------------
# Dataset:  Rectangle
# -----------------------------
#       Dataset                         Algorithm  Silhouette      Dunn  \
# 66  Rectangle                            KMeans    0.365392  0.007238
# 67  Rectangle                            DBSCAN    0.000000  0.000000
# 68  Rectangle                     Agglomerative    0.418023  0.137653
# 69  Rectangle                  CDSDG Clustering    0.495956  0.011770
# 70  Rectangle                      CDSDG Voting    0.495956  0.011770
# 71  Rectangle  CDSDG Clustering with n_clusters    0.365729  0.006781
#
#         Rand   Pearson
# 66  0.015470  0.127914
# 67  0.000000  0.000000
# 68  1.000000 -1.000000
# 69  0.500717 -0.464496
# 70  0.500717 -0.464496
# 71  0.024053 -0.158262
# -----------------------------
# Dataset:  Gaussian
# -----------------------------
#      Dataset                         Algorithm  Silhouette      Dunn  \
# 72  Gaussian                            KMeans    0.631302  0.077408
# 73  Gaussian                            DBSCAN    0.214779  0.114269
# 74  Gaussian                     Agglomerative    0.631471  0.092602
# 75  Gaussian                  CDSDG Clustering    0.421386  0.029300
# 76  Gaussian                      CDSDG Voting    0.008556  0.010058
# 77  Gaussian  CDSDG Clustering with n_clusters    0.631411  0.092602
#
#         Rand   Pearson
# 72  0.968192 -0.984031
# 73  0.000000 -0.044766
# 74  0.984032 -0.992000
# 75  0.925401 -0.927571
# 76  0.200580 -0.283349
# 77  0.976096  0.988008
# -----------------------------
# Dataset:  GaussianMix
# -----------------------------
#         Dataset                         Algorithm  Silhouette      Dunn  \
# 78  GaussianMix                            KMeans    0.689410  0.105251
# 79  GaussianMix                            DBSCAN    0.547011  0.179191
# 80  GaussianMix                     Agglomerative    0.689410  0.105251
# 81  GaussianMix                  CDSDG Clustering    0.676803  0.055938
# 82  GaussianMix                      CDSDG Voting    0.676803  0.055938
# 83  GaussianMix  CDSDG Clustering with n_clusters    0.689410  0.105251
#
#         Rand       Pearson
# 78  1.000000 -5.000000e-01
# 79  0.570609 -1.814847e-18
# 80  1.000000 -1.000000e+00
# 81  0.980134 -9.950238e-01
# 82  0.980134 -9.950238e-01
# 83  1.000000 -5.000000e-01
# -----------------------------
# Dataset:  Atom
# -----------------------------
#   Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 0    Atom                            KMeans    0.378657  0.027452  0.167421
# 1    Atom                            DBSCAN    0.460870  0.018507  0.567669
# 2    Atom                     Agglomerative    0.383773  0.068420  0.067072
# 3    Atom                  CDSDG Clustering    0.453309  0.036231  0.487792
# 4    Atom                      CDSDG Voting    0.453547  0.036231  0.482312
# 5    Atom  CDSDG Clustering with n_clusters    0.388044  0.027397  0.171543
#
#     Pearson
# 0  0.507801
# 1  0.915116
# 2 -0.386556
# 3 -0.297969
# 4 -0.295399
# 5  0.511693
# -----------------------------
# Dataset:  Chainlink
# -----------------------------
#       Dataset                         Algorithm  Silhouette      Dunn  \
# 6   Chainlink                            KMeans    0.255716  0.014675
# 7   Chainlink                            DBSCAN    0.153636  0.220721
# 8   Chainlink                     Agglomerative    0.271943  0.018816
# 9   Chainlink                  CDSDG Clustering    0.434951  0.009197
# 10  Chainlink                      CDSDG Voting    0.434951  0.009197
# 11  Chainlink  CDSDG Clustering with n_clusters    0.247633  0.014690
#
#         Rand   Pearson
# 6   0.207377  0.543449
# 7   1.000000  1.000000
# 8  -0.000902  0.008145
# 9   0.328304  0.426778
# 10  0.328304  0.426778
# 11  0.076371  0.279824
# -----------------------------
# Dataset:  EngyTime
# -----------------------------
#      Dataset                         Algorithm  Silhouette      Dunn  \
# 12  EngyTime                            KMeans    0.413282  0.004957
# 13  EngyTime                            DBSCAN    0.382455  0.035779
# 14  EngyTime                     Agglomerative    0.407908  0.003910
# 15  EngyTime                  CDSDG Clustering    0.414493  0.003058
# 16  EngyTime                      CDSDG Voting   -0.027951  0.001998
# 17  EngyTime  CDSDG Clustering with n_clusters    0.413367  0.000942
#
#         Rand   Pearson
# 12  0.812417  0.904415
# 13  0.000001 -0.027073
# 14  0.808021  0.902778
# 15  0.501168  0.725163
# 16  0.050413  0.293434
# 17  0.814179  0.905323
# -----------------------------
# Dataset:  Hepta
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn  Rand  \
# 18   Hepta                            KMeans    0.702131  1.049754   1.0
# 19   Hepta                            DBSCAN    0.702131  1.049754   1.0
# 20   Hepta                     Agglomerative    0.702131  1.049754   1.0
# 21   Hepta                  CDSDG Clustering    0.702131  1.049754   1.0
# 22   Hepta                      CDSDG Voting    0.702131  1.049754   1.0
# 23   Hepta  CDSDG Clustering with n_clusters    0.702131  1.049754   1.0
#
#      Pearson
# 18 -0.607086
# 19  1.000000
# 20 -0.440449
# 21  1.000000
# 22  1.000000
# 23  0.112892
# -----------------------------
# Dataset:  Tetra
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 24   Tetra                            KMeans    0.505794  0.223787  1.000000
# 25   Tetra                            DBSCAN    0.306610  0.101004  0.687028
# 26   Tetra                     Agglomerative    0.495199  0.142927  0.967268
# 27   Tetra                  CDSDG Clustering    0.496818  0.048211  0.973337
# 28   Tetra                      CDSDG Voting    0.492771  0.042320  0.966658
# 29   Tetra  CDSDG Clustering with n_clusters    0.492771  0.042320  0.966658
#
#      Pearson
# 24 -0.600000
# 25  0.839066
# 26  0.015008
# 27 -0.005976
# 28 -0.008965
# 29 -0.008965
# -----------------------------
# Dataset:  Target
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 30  Target                            KMeans    0.578341  0.013718  0.636675
# 31  Target                            DBSCAN    0.276200  0.116434  0.999635
# 32  Target                     Agglomerative    0.568308  0.044261  0.638779
# 33  Target                  CDSDG Clustering    0.550941  0.261923  0.029222
# 34  Target                      CDSDG Voting    0.342860  0.007502  0.059634
# 35  Target  CDSDG Clustering with n_clusters    0.580297  0.014137  0.634974
#
#      Pearson
# 30  0.706337
# 31  0.526598
# 32 -0.614411
# 33  0.414655
# 34  0.316822
# 35  0.696272
# -----------------------------
# Dataset:  TwoDiamonds
# -----------------------------
#         Dataset                         Algorithm  Silhouette      Dunn  \
# 36  TwoDiamonds                            KMeans    0.319035  0.016862
# 37  TwoDiamonds                            DBSCAN    0.000000  0.000000
# 38  TwoDiamonds                     Agglomerative    0.424732  0.017352
# 39  TwoDiamonds                  CDSDG Clustering    0.447150  0.015157
# 40  TwoDiamonds                      CDSDG Voting    0.447150  0.015157
# 41  TwoDiamonds  CDSDG Clustering with n_clusters    0.424732  0.017352
#
#         Rand   Pearson
# 36  0.039805 -0.202501
# 37  0.000000  0.000000
# 38  1.000000  1.000000
# 39  0.502073  0.467668
# 40  0.502073  0.467668
# 41  1.000000  1.000000
# -----------------------------
# Dataset:  WingNut
# -----------------------------
#     Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 42  WingNut                            KMeans    0.437988  0.015188  0.670268
# 43  WingNut                            DBSCAN    0.000000  0.000000  0.000000
# 44  WingNut                     Agglomerative    0.411792  0.071475  1.000000
# 45  WingNut                  CDSDG Clustering    0.415174  0.013936  0.520898
# 46  WingNut                      CDSDG Voting    0.280264  0.010203  0.361223
# 47  WingNut  CDSDG Clustering with n_clusters    0.437988  0.015188  0.670268
#
#      Pearson
# 42  0.818898
# 43  0.000000
# 44  1.000000
# 45  0.585621
# 46  0.468752
# 47  0.818898
# -----------------------------
# Dataset:  Iris
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 48    Iris                            KMeans    0.456535  0.077878  0.645147
# 49    Iris                            DBSCAN    0.356516  0.047926  0.442099
# 50    Iris                     Agglomerative    0.446689  0.098267  0.615323
# 51    Iris                  CDSDG Clustering    0.504646  0.239169  0.558371
# 52    Iris                      CDSDG Voting    0.292992  0.053693  0.536356
# 53    Iris  CDSDG Clustering with n_clusters    0.581750  0.267426  0.568116
#
#      Pearson
# 48 -0.574729
# 49  0.194046
# 50 -0.495993
# 51 -0.822466
# 52 -0.355202
# 53  0.866025
# -----------------------------
# Dataset:  Wine
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 54    Wine                            KMeans    0.285942  0.176897  0.914880
# 55    Wine                            DBSCAN    0.000000  0.000000  0.000000
# 56    Wine                     Agglomerative    0.277444  0.228586  0.789933
# 57    Wine                  CDSDG Clustering    0.251103  0.159888  0.834651
# 58    Wine                      CDSDG Voting    0.238268  0.175505  0.740649
# 59    Wine  CDSDG Clustering with n_clusters    0.284617  0.232257  0.913358
#
#      Pearson
# 54 -0.424356
# 55  0.000000
# 56 -0.515213
# 57 -0.340317
# 58 -0.358774
# 59 -0.508051
# -----------------------------
# Dataset:  Uniform
# -----------------------------
#     Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 60  Uniform                            KMeans    0.609070  0.004129  0.984032
# 61  Uniform                            DBSCAN    0.000000  0.000000  0.000000
# 62  Uniform                     Agglomerative    0.600847  0.014951  0.626526
# 63  Uniform                  CDSDG Clustering    0.572247  0.002531  0.469504
# 64  Uniform                      CDSDG Voting    0.572247  0.002531  0.469504
# 65  Uniform  CDSDG Clustering with n_clusters    0.609263  0.007647  0.968192
#
#      Pearson
# 60  0.992022
# 61  0.000000
# 62 -0.807947
# 63 -0.466066
# 64 -0.466066
# 65 -0.984111
# -----------------------------
# Dataset:  Rectangle
# -----------------------------
#       Dataset                         Algorithm  Silhouette      Dunn  \
# 66  Rectangle                            KMeans    0.365392  0.007238
# 67  Rectangle                            DBSCAN    0.000000  0.000000
# 68  Rectangle                     Agglomerative    0.418023  0.137653
# 69  Rectangle                  CDSDG Clustering    0.495956  0.011770
# 70  Rectangle                      CDSDG Voting    0.495956  0.011770
# 71  Rectangle  CDSDG Clustering with n_clusters    0.365729  0.006781
#
#         Rand   Pearson
# 66  0.015470  0.127914
# 67  0.000000  0.000000
# 68  1.000000 -1.000000
# 69  0.500717 -0.464496
# 70  0.500717 -0.464496
# 71  0.024053 -0.158262
# -----------------------------
# Dataset:  Gaussian
# -----------------------------
#      Dataset                         Algorithm  Silhouette      Dunn  \
# 72  Gaussian                            KMeans    0.631411  0.092602
# 73  Gaussian                            DBSCAN    0.214779  0.114269
# 74  Gaussian                     Agglomerative    0.631471  0.092602
# 75  Gaussian                  CDSDG Clustering    0.421386  0.029300
# 76  Gaussian                      CDSDG Voting    0.008150  0.010058
# 77  Gaussian  CDSDG Clustering with n_clusters    0.631411  0.092602
#
#         Rand   Pearson
# 72  0.976096 -0.988008
# 73  0.000000 -0.044766
# 74  0.984032 -0.992000
# 75  0.925401 -0.927571
# 76  0.198031 -0.266801
# 77  0.976096  0.988008
# -----------------------------
# Dataset:  GaussianMix
# -----------------------------
#         Dataset                         Algorithm  Silhouette      Dunn  \
# 78  GaussianMix                            KMeans    0.689410  0.105251
# 79  GaussianMix                            DBSCAN    0.547011  0.179191
# 80  GaussianMix                     Agglomerative    0.689410  0.105251
# 81  GaussianMix                  CDSDG Clustering    0.676803  0.055938
# 82  GaussianMix                      CDSDG Voting    0.676803  0.055938
# 83  GaussianMix  CDSDG Clustering with n_clusters    0.689410  0.105251
#
#         Rand       Pearson
# 78  1.000000 -1.000000e+00
# 79  0.570609 -1.814847e-18
# 80  1.000000 -1.000000e+00
# 81  0.980134 -9.950238e-01
# 82  0.980134 -9.950238e-01
# 83  1.000000 -5.000000e-01
# -----------------------------
# Dataset:  Atom
# -----------------------------
#   Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 0    Atom                            KMeans    0.389760  0.051867  0.149491
# 1    Atom                            DBSCAN    0.460870  0.018507  0.567669
# 2    Atom                     Agglomerative    0.383773  0.068420  0.067072
# 3    Atom                  CDSDG Clustering    0.453309  0.036231  0.487792
# 4    Atom                      CDSDG Voting    0.453309  0.036231  0.487792
# 5    Atom  CDSDG Clustering with n_clusters    0.388044  0.027397  0.171543
#
#     Pearson
# 0 -0.490214
# 1  0.915116
# 2 -0.386556
# 3 -0.297969
# 4 -0.297969
# 5  0.511693
# -----------------------------
# Dataset:  Chainlink
# -----------------------------
#       Dataset                         Algorithm  Silhouette      Dunn  \
# 6   Chainlink                            KMeans    0.267395  0.008944
# 7   Chainlink                            DBSCAN    0.153636  0.220721
# 8   Chainlink                     Agglomerative    0.271943  0.018816
# 9   Chainlink                  CDSDG Clustering    0.434735  0.009197
# 10  Chainlink                      CDSDG Voting    0.434951  0.009197
# 11  Chainlink  CDSDG Clustering with n_clusters    0.247633  0.014690
#
#         Rand   Pearson
# 6   0.220339 -0.554247
# 7   1.000000  1.000000
# 8  -0.000902  0.008145
# 9   0.333232  0.429956
# 10  0.328304  0.426778
# 11  0.076371  0.279824
# -----------------------------
# Dataset:  EngyTime
# -----------------------------
#      Dataset                         Algorithm  Silhouette      Dunn  \
# 12  EngyTime                            KMeans    0.413367  0.000942
# 13  EngyTime                            DBSCAN    0.382455  0.035779
# 14  EngyTime                     Agglomerative    0.407908  0.003910
# 15  EngyTime                  CDSDG Clustering    0.414493  0.003058
# 16  EngyTime                      CDSDG Voting   -0.027951  0.001998
# 17  EngyTime  CDSDG Clustering with n_clusters    0.413367  0.000942
#
#         Rand   Pearson
# 12  0.814179 -0.905323
# 13  0.000001 -0.027073
# 14  0.808021  0.902778
# 15  0.501168  0.725163
# 16  0.050413  0.293434
# 17  0.814179  0.905323
# -----------------------------
# Dataset:  Hepta
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn  Rand  \
# 18   Hepta                            KMeans    0.702131  1.049754   1.0
# 19   Hepta                            DBSCAN    0.702131  1.049754   1.0
# 20   Hepta                     Agglomerative    0.702131  1.049754   1.0
# 21   Hepta                  CDSDG Clustering    0.702131  1.049754   1.0
# 22   Hepta                      CDSDG Voting    0.702131  1.049754   1.0
# 23   Hepta  CDSDG Clustering with n_clusters    0.702131  1.049754   1.0
#
#      Pearson
# 18  0.006993
# 19  1.000000
# 20 -0.440449
# 21  1.000000
# 22  1.000000
# 23  0.112892
# -----------------------------
# Dataset:  Tetra
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 24   Tetra                            KMeans    0.505794  0.223787  1.000000
# 25   Tetra                            DBSCAN    0.306610  0.101004  0.687028
# 26   Tetra                     Agglomerative    0.495199  0.142927  0.967268
# 27   Tetra                  CDSDG Clustering    0.493585  0.042320  0.966724
# 28   Tetra                      CDSDG Voting    0.492771  0.042320  0.966658
# 29   Tetra  CDSDG Clustering with n_clusters    0.492771  0.042320  0.966658
#
#      Pearson
# 24  0.200000
# 25  0.839066
# 26  0.015008
# 27 -0.005965
# 28 -0.008965
# 29 -0.008965
# -----------------------------
# Dataset:  Target
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 30  Target                            KMeans    0.572456  0.023734  0.634739
# 31  Target                            DBSCAN    0.276200  0.116434  0.999635
# 32  Target                     Agglomerative    0.568308  0.044261  0.638779
# 33  Target                  CDSDG Clustering    0.550941  0.261923  0.029222
# 34  Target                      CDSDG Voting    0.342860  0.007502  0.059634
# 35  Target  CDSDG Clustering with n_clusters    0.580701  0.015461  0.635136
#
#      Pearson
# 30  0.724016
# 31  0.526598
# 32 -0.614411
# 33  0.414655
# 34  0.316822
# 35  0.723725
# -----------------------------
# Dataset:  TwoDiamonds
# -----------------------------
#         Dataset                         Algorithm  Silhouette      Dunn  \
# 36  TwoDiamonds                            KMeans    0.424732  0.017352
# 37  TwoDiamonds                            DBSCAN    0.000000  0.000000
# 38  TwoDiamonds                     Agglomerative    0.424732  0.017352
# 39  TwoDiamonds                  CDSDG Clustering    0.447150  0.015157
# 40  TwoDiamonds                      CDSDG Voting    0.447150  0.015157
# 41  TwoDiamonds  CDSDG Clustering with n_clusters    0.424732  0.017352
#
#         Rand   Pearson
# 36  1.000000  1.000000
# 37  0.000000  0.000000
# 38  1.000000  1.000000
# 39  0.502073  0.467668
# 40  0.502073  0.467668
# 41  1.000000  1.000000
# -----------------------------
# Dataset:  WingNut
# -----------------------------
#     Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 42  WingNut                            KMeans    0.437988  0.015188  0.670268
# 43  WingNut                            DBSCAN    0.000000  0.000000  0.000000
# 44  WingNut                     Agglomerative    0.411792  0.071475  1.000000
# 45  WingNut                  CDSDG Clustering    0.415174  0.013936  0.520898
# 46  WingNut                      CDSDG Voting    0.280264  0.010203  0.361223
# 47  WingNut  CDSDG Clustering with n_clusters    0.437988  0.015188  0.670268
#
#      Pearson
# 42  0.818898
# 43  0.000000
# 44  1.000000
# 45  0.585621
# 46  0.468752
# 47  0.818898
# -----------------------------
# Dataset:  Iris
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 48    Iris                            KMeans    0.456535  0.077878  0.645147
# 49    Iris                            DBSCAN    0.356516  0.047926  0.442099
# 50    Iris                     Agglomerative    0.446689  0.098267  0.615323
# 51    Iris                  CDSDG Clustering    0.504646  0.239169  0.558371
# 52    Iris                      CDSDG Voting    0.292992  0.053693  0.536356
# 53    Iris  CDSDG Clustering with n_clusters    0.581750  0.267426  0.568116
#
#      Pearson
# 48  0.349198
# 49  0.194046
# 50 -0.495993
# 51 -0.822466
# 52 -0.355202
# 53  0.866025
# -----------------------------
# Dataset:  Wine
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 54    Wine                            KMeans    0.284859  0.232257  0.897495
# 55    Wine                            DBSCAN    0.000000  0.000000  0.000000
# 56    Wine                     Agglomerative    0.277444  0.228586  0.789933
# 57    Wine                  CDSDG Clustering    0.247314  0.224654  0.820161
# 58    Wine                      CDSDG Voting    0.233602  0.159888  0.721896
# 59    Wine  CDSDG Clustering with n_clusters    0.281317  0.178970  0.882058
#
#      Pearson
# 54 -0.426458
# 55  0.000000
# 56 -0.515213
# 57 -0.369885
# 58 -0.346985
# 59 -0.516626
# -----------------------------
# Dataset:  Uniform
# -----------------------------
#     Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 60  Uniform                            KMeans    0.609070  0.004129  0.984032
# 61  Uniform                            DBSCAN    0.000000  0.000000  0.000000
# 62  Uniform                     Agglomerative    0.600847  0.014951  0.626526
# 63  Uniform                  CDSDG Clustering    0.572247  0.002531  0.469504
# 64  Uniform                      CDSDG Voting    0.572247  0.002531  0.469504
# 65  Uniform  CDSDG Clustering with n_clusters    0.609263  0.007647  0.968192
#
#      Pearson
# 60 -0.992022
# 61  0.000000
# 62 -0.807947
# 63 -0.466066
# 64 -0.466066
# 65 -0.984111
# -----------------------------
# Dataset:  Rectangle
# -----------------------------
#       Dataset                         Algorithm  Silhouette      Dunn  \
# 66  Rectangle                            KMeans    0.418023  0.137653
# 67  Rectangle                            DBSCAN    0.000000  0.000000
# 68  Rectangle                     Agglomerative    0.418023  0.137653
# 69  Rectangle                  CDSDG Clustering    0.495956  0.011770
# 70  Rectangle                      CDSDG Voting    0.495956  0.011770
# 71  Rectangle  CDSDG Clustering with n_clusters    0.365729  0.006781
#
#         Rand   Pearson
# 66  1.000000  1.000000
# 67  0.000000  0.000000
# 68  1.000000 -1.000000
# 69  0.500717 -0.464496
# 70  0.500717 -0.464496
# 71  0.024053 -0.158262
# -----------------------------
# Dataset:  Gaussian
# -----------------------------
#      Dataset                         Algorithm  Silhouette      Dunn  \
# 72  Gaussian                            KMeans    0.631302  0.077408
# 73  Gaussian                            DBSCAN    0.214779  0.114269
# 74  Gaussian                     Agglomerative    0.631471  0.092602
# 75  Gaussian                  CDSDG Clustering    0.421386  0.029300
# 76  Gaussian                      CDSDG Voting    0.008150  0.010058
# 77  Gaussian  CDSDG Clustering with n_clusters    0.631411  0.092602
#
#         Rand   Pearson
# 72  0.968192 -0.984031
# 73  0.000000 -0.044766
# 74  0.984032 -0.992000
# 75  0.925401 -0.927571
# 76  0.198031 -0.266801
# 77  0.976096  0.988008
# -----------------------------
# Dataset:  GaussianMix
# -----------------------------
#         Dataset                         Algorithm  Silhouette      Dunn  \
# 78  GaussianMix                            KMeans    0.689410  0.105251
# 79  GaussianMix                            DBSCAN    0.547011  0.179191
# 80  GaussianMix                     Agglomerative    0.689410  0.105251
# 81  GaussianMix                  CDSDG Clustering    0.676803  0.055938
# 82  GaussianMix                      CDSDG Voting    0.676803  0.055938
# 83  GaussianMix  CDSDG Clustering with n_clusters    0.689410  0.105251
#
#         Rand       Pearson
# 78  1.000000 -1.000000e+00
# 79  0.570609 -1.814847e-18
# 80  1.000000 -1.000000e+00
# 81  0.980134 -9.950238e-01
# 82  0.980134 -9.950238e-01
# 83  1.000000 -5.000000e-01
# -----------------------------
# Dataset:  Atom
# -----------------------------
#   Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 0    Atom                            KMeans    0.389564  0.073150  0.175715
# 1    Atom                            DBSCAN    0.460870  0.018507  0.567669
# 2    Atom                     Agglomerative    0.383773  0.068420  0.067072
# 3    Atom                  CDSDG Clustering    0.453309  0.036231  0.487792
# 4    Atom                      CDSDG Voting    0.453309  0.036231  0.487792
# 5    Atom  CDSDG Clustering with n_clusters    0.388435  0.027397  0.173623
#
#     Pearson
# 0  0.515580
# 1  0.915116
# 2 -0.386556
# 3 -0.297969
# 4 -0.297969
# 5  0.513637
# -----------------------------
# Dataset:  Chainlink
# -----------------------------
#       Dataset                         Algorithm  Silhouette      Dunn  \
# 6   Chainlink                            KMeans    0.281948  0.019085
# 7   Chainlink                            DBSCAN    0.153636  0.220721
# 8   Chainlink                     Agglomerative    0.271943  0.018816
# 9   Chainlink                  CDSDG Clustering    0.434951  0.009197
# 10  Chainlink                      CDSDG Voting    0.434951  0.009197
# 11  Chainlink  CDSDG Clustering with n_clusters    0.247633  0.014690
#
#         Rand   Pearson
# 6  -0.000806 -0.014001
# 7   1.000000  1.000000
# 8  -0.000902  0.008145
# 9   0.328304  0.426778
# 10  0.328304  0.426778
# 11  0.076371  0.279824
# -----------------------------
# Dataset:  EngyTime
# -----------------------------
#      Dataset                         Algorithm  Silhouette      Dunn  \
# 12  EngyTime                            KMeans    0.413282  0.004957
# 13  EngyTime                            DBSCAN    0.382455  0.035779
# 14  EngyTime                     Agglomerative    0.407908  0.003910
# 15  EngyTime                  CDSDG Clustering    0.414493  0.003058
# 16  EngyTime                      CDSDG Voting   -0.020075  0.002094
# 17  EngyTime  CDSDG Clustering with n_clusters    0.413367  0.000942
#
#         Rand   Pearson
# 12  0.812417 -0.904415
# 13  0.000001 -0.027073
# 14  0.808021  0.902778
# 15  0.501168  0.725163
# 16  0.053267  0.303978
# 17  0.814179  0.905323
# -----------------------------
# Dataset:  Hepta
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn  Rand  \
# 18   Hepta                            KMeans    0.702131  1.049754   1.0
# 19   Hepta                            DBSCAN    0.702131  1.049754   1.0
# 20   Hepta                     Agglomerative    0.702131  1.049754   1.0
# 21   Hepta                  CDSDG Clustering    0.702131  1.049754   1.0
# 22   Hepta                      CDSDG Voting    0.702131  1.049754   1.0
# 23   Hepta  CDSDG Clustering with n_clusters    0.702131  1.049754   1.0
#
#      Pearson
# 18 -0.126765
# 19  1.000000
# 20 -0.440449
# 21  1.000000
# 22  1.000000
# 23  0.112892
# -----------------------------
# Dataset:  Tetra
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 24   Tetra                            KMeans    0.505794  0.223787  1.000000
# 25   Tetra                            DBSCAN    0.306610  0.101004  0.687028
# 26   Tetra                     Agglomerative    0.495199  0.142927  0.967268
# 27   Tetra                  CDSDG Clustering    0.496818  0.048211  0.973337
# 28   Tetra                      CDSDG Voting    0.492771  0.042320  0.966658
# 29   Tetra  CDSDG Clustering with n_clusters    0.488794  0.042320  0.960144
#
#      Pearson
# 24 -0.400000
# 25  0.839066
# 26  0.015008
# 27 -0.005976
# 28 -0.008965
# 29 -0.010980
# -----------------------------
# Dataset:  Target
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 30  Target                            KMeans    0.573275  0.011541  0.657707
# 31  Target                            DBSCAN    0.276200  0.116434  0.999635
# 32  Target                     Agglomerative    0.568308  0.044261  0.638779
# 33  Target                  CDSDG Clustering    0.550941  0.261923  0.029222
# 34  Target                      CDSDG Voting    0.342860  0.007502  0.059634
# 35  Target  CDSDG Clustering with n_clusters    0.580701  0.015461  0.635136
#
#      Pearson
# 30  0.443553
# 31  0.526598
# 32 -0.614411
# 33  0.414655
# 34  0.316822
# 35  0.723725
# -----------------------------
# Dataset:  TwoDiamonds
# -----------------------------
#         Dataset                         Algorithm  Silhouette      Dunn  \
# 36  TwoDiamonds                            KMeans    0.424732  0.017352
# 37  TwoDiamonds                            DBSCAN    0.000000  0.000000
# 38  TwoDiamonds                     Agglomerative    0.424732  0.017352
# 39  TwoDiamonds                  CDSDG Clustering    0.447150  0.015157
# 40  TwoDiamonds                      CDSDG Voting    0.447150  0.015157
# 41  TwoDiamonds  CDSDG Clustering with n_clusters    0.424732  0.017352
#
#         Rand   Pearson
# 36  1.000000  1.000000
# 37  0.000000  0.000000
# 38  1.000000  1.000000
# 39  0.502073  0.467668
# 40  0.502073  0.467668
# 41  1.000000  1.000000
# -----------------------------
# Dataset:  WingNut
# -----------------------------
#     Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 42  WingNut                            KMeans    0.437990  0.013645  0.679985
# 43  WingNut                            DBSCAN    0.000000  0.000000  0.000000
# 44  WingNut                     Agglomerative    0.411792  0.071475  1.000000
# 45  WingNut                  CDSDG Clustering    0.415174  0.013936  0.520898
# 46  WingNut                      CDSDG Voting    0.280264  0.010203  0.361223
# ...
# 39  0.502073  0.467668
# 40  0.502073  0.467668
# 41  1.000000  1.000000
# -----------------------------
# Dataset:  WingNut
# -----------------------------
#     Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 42  WingNut                            KMeans    0.437988  0.015188  0.670268
# 43  WingNut                            DBSCAN    0.000000  0.000000  0.000000
# 44  WingNut                     Agglomerative    0.411792  0.071475  1.000000
# 45  WingNut                  CDSDG Clustering    0.415174  0.013936  0.520898
# 46  WingNut                      CDSDG Voting    0.279990  0.010203  0.362085
# 47  WingNut  CDSDG Clustering with n_clusters    0.437988  0.015188  0.670268
#
#      Pearson
# 42  0.818898
# 43  0.000000
# 44  1.000000
# 45  0.585621
# 46  0.469957
# 47  0.818898
# -----------------------------
# Dataset:  Iris
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 48    Iris                            KMeans    0.463042  0.057119  0.592333
# 49    Iris                            DBSCAN    0.356516  0.047926  0.442099
# 50    Iris                     Agglomerative    0.446689  0.098267  0.615323
# 51    Iris                  CDSDG Clustering    0.504646  0.239169  0.558371
# 52    Iris                      CDSDG Voting    0.292992  0.053693  0.536356
# 53    Iris  CDSDG Clustering with n_clusters    0.581750  0.267426  0.568116
#
#      Pearson
# 48  0.651499
# 49  0.194046
# 50 -0.495993
# 51 -0.822466
# 52 -0.355202
# 53  0.866025
# -----------------------------
# Dataset:  Wine
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 54    Wine                            KMeans    0.285942  0.176897  0.914880
# 55    Wine                            DBSCAN    0.000000  0.000000  0.000000
# 56    Wine                     Agglomerative    0.277444  0.228586  0.789933
# 57    Wine                  CDSDG Clustering    0.265237  0.145307  0.818489
# 58    Wine                      CDSDG Voting    0.221565  0.159888  0.690365
# 59    Wine  CDSDG Clustering with n_clusters    0.276686  0.198965  0.882254
#
#      Pearson
# 54  0.424356
# 55  0.000000
# 56 -0.515213
# 57 -0.437451
# 58 -0.347325
# 59 -0.522420
# -----------------------------
# Dataset:  Uniform
# -----------------------------
#     Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 60  Uniform                            KMeans    0.609070  0.004129  0.984032
# 61  Uniform                            DBSCAN    0.000000  0.000000  0.000000
# 62  Uniform                     Agglomerative    0.600847  0.014951  0.626526
# 63  Uniform                  CDSDG Clustering    0.572247  0.002531  0.469504
# 64  Uniform                      CDSDG Voting    0.572247  0.002531  0.469504
# 65  Uniform  CDSDG Clustering with n_clusters    0.609263  0.007647  0.968192
#
#      Pearson
# 60  0.992022
# 61  0.000000
# 62 -0.807947
# 63 -0.466066
# 64 -0.466066
# 65 -0.984111
# -----------------------------
# Dataset:  Rectangle
# -----------------------------
#       Dataset                         Algorithm  Silhouette      Dunn  \
# 66  Rectangle                            KMeans    0.365385  0.007238
# 67  Rectangle                            DBSCAN    0.000000  0.000000
# 68  Rectangle                     Agglomerative    0.418023  0.137653
# 69  Rectangle                  CDSDG Clustering    0.495956  0.011770
# 70  Rectangle                      CDSDG Voting    0.495956  0.011770
# 71  Rectangle  CDSDG Clustering with n_clusters    0.365729  0.006781
#
#         Rand   Pearson
# 66  0.015877 -0.129465
# 67  0.000000  0.000000
# 68  1.000000 -1.000000
# 69  0.500717 -0.464496
# 70  0.500717 -0.464496
# 71  0.024053 -0.158262
# -----------------------------
# Dataset:  Gaussian
# -----------------------------
#      Dataset                         Algorithm  Silhouette      Dunn  \
# 72  Gaussian                            KMeans    0.631411  0.092602
# 73  Gaussian                            DBSCAN    0.214779  0.114269
# 74  Gaussian                     Agglomerative    0.631471  0.092602
# 75  Gaussian                  CDSDG Clustering    0.421386  0.029300
# 76  Gaussian                      CDSDG Voting   -0.012653  0.008639
# 77  Gaussian  CDSDG Clustering with n_clusters    0.631411  0.092602
#
#         Rand   Pearson
# 72  0.976096  0.988008
# 73  0.000000 -0.044766
# 74  0.984032 -0.992000
# 75  0.925401 -0.927571
# 76  0.191064 -0.267033
# 77  0.976096  0.988008
# -----------------------------
# Dataset:  GaussianMix
# -----------------------------
#         Dataset                         Algorithm  Silhouette      Dunn  \
# 78  GaussianMix                            KMeans    0.689410  0.105251
# 79  GaussianMix                            DBSCAN    0.547011  0.179191
# 80  GaussianMix                     Agglomerative    0.689410  0.105251
# 81  GaussianMix                  CDSDG Clustering    0.676803  0.055938
# 82  GaussianMix                      CDSDG Voting    0.676803  0.055938
# 83  GaussianMix  CDSDG Clustering with n_clusters    0.689410  0.105251
#
#         Rand       Pearson
# 78  1.000000  5.000000e-01
# 79  0.570609 -1.814847e-18
# 80  1.000000 -1.000000e+00
# 81  0.980134 -9.950238e-01
# 82  0.980134 -9.950238e-01
# 83  1.000000 -5.000000e-01
# -----------------------------
# Dataset:  Atom
# -----------------------------
#   Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 0    Atom                            KMeans    0.382334  0.031150  0.134406
# 1    Atom                            DBSCAN    0.460870  0.018507  0.567669
# 2    Atom                     Agglomerative    0.383773  0.068420  0.067072
# 3    Atom                  CDSDG Clustering    0.453309  0.036231  0.487792
# 4    Atom                      CDSDG Voting    0.453309  0.036231  0.487792
# 5    Atom  CDSDG Clustering with n_clusters    0.388044  0.027397  0.171543
#
#     Pearson
# 0 -0.474463
# 1  0.915116
# 2 -0.386556
# 3 -0.297969
# 4 -0.297969
# 5  0.511693
# -----------------------------
# Dataset:  Chainlink
# -----------------------------
#       Dataset                         Algorithm  Silhouette      Dunn  \
# 6   Chainlink                            KMeans    0.283379  0.016326
# 7   Chainlink                            DBSCAN    0.153636  0.220721
# 8   Chainlink                     Agglomerative    0.271943  0.018816
# 9   Chainlink                  CDSDG Clustering    0.438574  0.009917
# 10  Chainlink                      CDSDG Voting    0.434951  0.009197
# 11  Chainlink  CDSDG Clustering with n_clusters    0.247633  0.014690
#
#         Rand   Pearson
# 6  -0.000806 -0.014000
# 7   1.000000  1.000000
# 8  -0.000902  0.008145
# 9   0.328104  0.423720
# 10  0.328304  0.426778
# 11  0.076371  0.279824
# -----------------------------
# Dataset:  EngyTime
# -----------------------------
#      Dataset                         Algorithm  Silhouette      Dunn  \
# 12  EngyTime                            KMeans    0.413367  0.000942
# 13  EngyTime                            DBSCAN    0.382455  0.035779
# 14  EngyTime                     Agglomerative    0.407908  0.003910
# 15  EngyTime                  CDSDG Clustering    0.414493  0.003058
# 16  EngyTime                      CDSDG Voting   -0.020075  0.002094
# 17  EngyTime  CDSDG Clustering with n_clusters    0.413367  0.000942
#
#         Rand   Pearson
# 12  0.814179 -0.905323
# 13  0.000001 -0.027073
# 14  0.808021  0.902778
# 15  0.501168  0.725163
# 16  0.053267  0.303978
# 17  0.814179  0.905323
# -----------------------------
# Dataset:  Hepta
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn  Rand  \
# 18   Hepta                            KMeans    0.702131  1.049754   1.0
# 19   Hepta                            DBSCAN    0.702131  1.049754   1.0
# 20   Hepta                     Agglomerative    0.702131  1.049754   1.0
# 21   Hepta                  CDSDG Clustering    0.702131  1.049754   1.0
# 22   Hepta                      CDSDG Voting    0.702131  1.049754   1.0
# 23   Hepta  CDSDG Clustering with n_clusters    0.702131  1.049754   1.0
#
#      Pearson
# 18  0.176706
# 19  1.000000
# 20 -0.440449
# 21  1.000000
# 22  1.000000
# 23  0.112892
# -----------------------------
# Dataset:  Tetra
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 24   Tetra                            KMeans    0.505794  0.223787  1.000000
# 25   Tetra                            DBSCAN    0.306610  0.101004  0.687028
# 26   Tetra                     Agglomerative    0.495199  0.142927  0.967268
# 27   Tetra                  CDSDG Clustering    0.492771  0.042320  0.966658
# 28   Tetra                      CDSDG Voting    0.488794  0.042320  0.960144
# 29   Tetra  CDSDG Clustering with n_clusters    0.489283  0.042320  0.960144
#
#      Pearson
# 24  0.800000
# 25  0.839066
# 26  0.015008
# 27 -0.008965
# 28 -0.010980
# 29 -0.010980
# -----------------------------
# Dataset:  Target
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 30  Target                            KMeans    0.576233  0.013656  0.634315
# 31  Target                            DBSCAN    0.276200  0.116434  0.999635
# 32  Target                     Agglomerative    0.568308  0.044261  0.638779
# 33  Target                  CDSDG Clustering    0.550941  0.261923  0.029222
# 34  Target                      CDSDG Voting    0.336525  0.008522  0.056942
# 35  Target  CDSDG Clustering with n_clusters    0.580701  0.015461  0.635136
#
#      Pearson
# 30  0.490424
# 31  0.526598
# 32 -0.614411
# 33  0.414655
# 34  0.313043
# 35  0.723725
# -----------------------------
# Dataset:  TwoDiamonds
# -----------------------------
#         Dataset                         Algorithm  Silhouette      Dunn  \
# 36  TwoDiamonds                            KMeans    0.319035  0.016862
# 37  TwoDiamonds                            DBSCAN    0.000000  0.000000
# 38  TwoDiamonds                     Agglomerative    0.424732  0.017352
# 39  TwoDiamonds                  CDSDG Clustering    0.447150  0.015157
# 40  TwoDiamonds                      CDSDG Voting    0.447150  0.015157
# 41  TwoDiamonds  CDSDG Clustering with n_clusters    0.424732  0.017352
#
#         Rand   Pearson
# 36  0.039805  0.202501
# 37  0.000000  0.000000
# 38  1.000000  1.000000
# 39  0.502073  0.467668
# 40  0.502073  0.467668
# 41  1.000000  1.000000
# -----------------------------
# Dataset:  WingNut
# -----------------------------
#     Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 42  WingNut                            KMeans    0.437988  0.015188  0.670268
# 43  WingNut                            DBSCAN    0.000000  0.000000  0.000000
# 44  WingNut                     Agglomerative    0.411792  0.071475  1.000000
# 45  WingNut                  CDSDG Clustering    0.415174  0.013936  0.520898
# 46  WingNut                      CDSDG Voting    0.280264  0.010203  0.361223
# 47  WingNut  CDSDG Clustering with n_clusters    0.437988  0.015188  0.670268
#
#      Pearson
# 42  0.818898
# 43  0.000000
# 44  1.000000
# 45  0.585621
# 46  0.468752
# 47  0.818898
# -----------------------------
# Dataset:  Iris
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 48    Iris                            KMeans    0.459378  0.026497  0.610073
# 49    Iris                            DBSCAN    0.356516  0.047926  0.442099
# 50    Iris                     Agglomerative    0.446689  0.098267  0.615323
# 51    Iris                  CDSDG Clustering    0.504646  0.239169  0.558371
# 52    Iris                      CDSDG Voting    0.292992  0.053693  0.536356
# 53    Iris  CDSDG Clustering with n_clusters    0.581750  0.267426  0.568116
#
#      Pearson
# 48 -0.220117
# 49  0.194046
# 50 -0.495993
# 51 -0.822466
# 52 -0.355202
# 53  0.866025
# -----------------------------
# Dataset:  Wine
# -----------------------------
#    Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 54    Wine                            KMeans    0.285942  0.176897  0.914880
# 55    Wine                            DBSCAN    0.000000  0.000000  0.000000
# 56    Wine                     Agglomerative    0.277444  0.228586  0.789933
# 57    Wine                  CDSDG Clustering    0.257449  0.159888  0.834495
# 58    Wine                      CDSDG Voting    0.217510  0.159888  0.679695
# 59    Wine  CDSDG Clustering with n_clusters    0.276686  0.198965  0.882254
#
#      Pearson
# 54 -0.510683
# 55  0.000000
# 56 -0.515213
# 57 -0.358808
# 58 -0.346989
# 59 -0.522420
# -----------------------------
# Dataset:  Uniform
# -----------------------------
#     Dataset                         Algorithm  Silhouette      Dunn      Rand  \
# 60  Uniform                            KMeans    0.609263  0.007647  0.968192
# 61  Uniform                            DBSCAN    0.000000  0.000000  0.000000
# 62  Uniform                     Agglomerative    0.600847  0.014951  0.626526
# 63  Uniform                  CDSDG Clustering    0.572247  0.002531  0.469504
# 64  Uniform                      CDSDG Voting    0.572247  0.002531  0.469504
# 65  Uniform  CDSDG Clustering with n_clusters    0.609263  0.007647  0.968192
#
#      Pearson
# 60 -0.984111
# 61  0.000000
# 62 -0.807947
# 63 -0.466066
# 64 -0.466066
# 65 -0.984111
# -----------------------------
# Dataset:  Rectangle
# -----------------------------
#       Dataset                         Algorithm  Silhouette      Dunn  \
# 66  Rectangle                            KMeans    0.418023  0.137653
# 67  Rectangle                            DBSCAN    0.000000  0.000000
# 68  Rectangle                     Agglomerative    0.418023  0.137653
# 69  Rectangle                  CDSDG Clustering    0.495956  0.011770
# 70  Rectangle                      CDSDG Voting    0.495956  0.011770
# 71  Rectangle  CDSDG Clustering with n_clusters    0.365729  0.006781
#
#         Rand   Pearson
# 66  1.000000 -1.000000
# 67  0.000000  0.000000
# 68  1.000000 -1.000000
# 69  0.500717 -0.464496
# 70  0.500717 -0.464496
# 71  0.024053 -0.158262
# -----------------------------
# Dataset:  Gaussian
# -----------------------------
#      Dataset                         Algorithm  Silhouette      Dunn  \
# 72  Gaussian                            KMeans    0.631411  0.092602
# 73  Gaussian                            DBSCAN    0.214779  0.114269
# 74  Gaussian                     Agglomerative    0.631471  0.092602
# 75  Gaussian                  CDSDG Clustering    0.421386  0.029300
# 76  Gaussian                      CDSDG Voting   -0.011363  0.008639
# 77  Gaussian  CDSDG Clustering with n_clusters    0.631411  0.092602
#
#         Rand   Pearson
# 72  0.976096  0.988008
# 73  0.000000 -0.044766
# 74  0.984032 -0.992000
# 75  0.925401 -0.927571
# 76  0.193516 -0.276460
# 77  0.976096  0.988008
# -----------------------------
# Dataset:  GaussianMix
# -----------------------------
#         Dataset                         Algorithm  Silhouette      Dunn  \
# 78  GaussianMix                            KMeans    0.689410  0.105251
# 79  GaussianMix                            DBSCAN    0.547011  0.179191
# 80  GaussianMix                     Agglomerative    0.689410  0.105251
# 81  GaussianMix                  CDSDG Clustering    0.676803  0.055938
# 82  GaussianMix                      CDSDG Voting    0.676803  0.055938
# 83  GaussianMix  CDSDG Clustering with n_clusters    0.689410  0.105251
#
#         Rand       Pearson
# 78  1.000000 -5.000000e-01
# 79  0.570609 -1.814847e-18
# 80  1.000000 -1.000000e+00
# 81  0.980134 -9.950238e-01
# 82  0.980134 -9.950238e-01
# 83  1.000000 -5.000000e-01
# -----------------------------
