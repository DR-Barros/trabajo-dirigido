# %%
import pandas as pd
import numpy as np

from dsgd.DSClassifierMultiQ import DSClassifierMultiQ

from sklearn.metrics import accuracy_score, confusion_matrix, f1_score

# %%
df = pd.read_csv("https://huggingface.co/datasets/furrutiav/sac_nllf/raw/main/train.csv")
df = df.drop(columns=['index', "b1(N)", "b2(N)", "b3(N)", "b4(N)", "b5(N)", "b6(N)", "b7(N)", "b8(N)", "b9(N)", "b10(N)", "b11(N)", "b12(N)", "b13(N)"])
print("Dataframe shape: ", df.shape)
df.head()
test = pd.read_csv("https://huggingface.co/datasets/furrutiav/sac_nllf/raw/main/test.csv")
test = test.drop(columns=['index', "b1(N)", "b2(N)", "b3(N)", "b4(N)", "b5(N)", "b6(N)", "b7(N)", "b8(N)", "b9(N)", "b10(N)", "b11(N)", "b12(N)", "b13(N)"])
print("Dataframe shape: ", test.shape)
# Out:
# Dataframe shape:  (1400, 14)
# Dataframe shape:  (400, 14)

# %%
y = df['label']
X = df.drop(columns=['label'])
y = y.to_numpy()
X = X.to_numpy()    
y_test = test['label']
X_test = test.drop(columns=['label'])
X_test = X_test.to_numpy()
y_test = y_test.to_numpy()

# %%
DSCs = {}
time = {}
accuracys = {}
learning_rates = [0.0001,]
batch_sizes = [2000, 3000, 4000]
min_dl = [1e-7, 1e-6, 1e-5,]
num_rules = [3, 5, 7,]
df_results = pd.DataFrame(columns=['lr', 'bs', 'mdl', 'nr', 'accuracy', 'f1_micro', 'f1_macro'])
results = []
for lr in learning_rates:
    for bs in batch_sizes:
        for mdl in min_dl:
            for nr in num_rules:
                DSC = DSClassifierMultiQ(2, min_iter=20, max_iter=500, debug_mode=True, lr=lr, batch_size=bs,
                                lossfn="MSE", num_workers=1, min_dloss=mdl, precompute_rules=True)
                print(f"Training DSC with lr={lr}, bs={bs}, mdl={mdl}, nr={nr}")
                losses, epoch, dt = DSC.fit(X, y, add_single_rules=True,
                            single_rules_breaks=nr, add_mult_rules=False,
                                column_names=df.columns[:-1], print_every_epochs=1, print_final_model=False)
                y_pred = DSC.predict(X_test)
                acc = accuracy_score(y_test, y_pred)
                f1_micro = f1_score(y_test, y_pred, average='micro')
                f1_macro = f1_score(y_test, y_pred, average='macro')
                print(f"Accuracy: {acc}, F1 micro: {f1_micro}, F1 macro: {f1_macro}")
                new_row = pd.DataFrame({
                    'lr': [lr], 'bs': [bs], 'mdl': [mdl], 'nr': [nr],
                    'accuracy': [acc], 'f1_micro': [f1_micro], 'f1_macro': [f1_macro]
                })
                df_results = pd.concat([df_results, new_row])
                results.append({
                    'lr': lr, 'bs': bs, 'mdl': mdl, 'nr': nr,
                    'accuracy': acc, 'f1_micro': f1_micro, 'f1_macro': f1_macro
                })
                

df_results.to_csv("results_pos.csv", index=False)
# Out:
# Training DSC with lr=0.0001, bs=2000, mdl=1e-07, nr=3
# Optimization started
# Processing epoch	500	0.2377
# Training time: 1213.97s, epochs: 500
#
# Least training loss reached: 0.238
# Accuracy: 0.62, F1 micro: 0.62, F1 macro: 0.6190476190476191
# Training DSC with lr=0.0001, bs=2000, mdl=1e-07, nr=5
# Optimization started
# Processing epoch	1	1.0000
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_18644\2237322864.py:29: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_results = pd.concat([df_results, new_row])
# Processing epoch	500	0.2319
# Training time: 1177.36s, epochs: 500
#
# Least training loss reached: 0.232
# Accuracy: 0.6175, F1 micro: 0.6175, F1 macro: 0.6125969298939706
# Training DSC with lr=0.0001, bs=2000, mdl=1e-07, nr=7
# Optimization started
# Processing epoch	500	0.2227
# Training time: 1202.16s, epochs: 500
#
# Least training loss reached: 0.223
# Accuracy: 0.675, F1 micro: 0.675, F1 macro: 0.6713769306605324
# Training DSC with lr=0.0001, bs=2000, mdl=1e-06, nr=3
# Optimization started
# Processing epoch	500	0.2289
# Training time: 1203.10s, epochs: 500
#
# Least training loss reached: 0.229
# Accuracy: 0.64, F1 micro: 0.64, F1 macro: 0.6382273138378052
# Training DSC with lr=0.0001, bs=2000, mdl=1e-06, nr=5
# Optimization started
# Processing epoch	500	0.2186
# Training time: 1208.55s, epochs: 500
#
# Least training loss reached: 0.219
# Accuracy: 0.655, F1 micro: 0.655, F1 macro: 0.6544471153846154
# Training DSC with lr=0.0001, bs=2000, mdl=1e-06, nr=7
# Optimization started
# Processing epoch	500	0.2187
# Training time: 1173.98s, epochs: 500
#
# Least training loss reached: 0.219
# Accuracy: 0.6975, F1 micro: 0.6975, F1 macro: 0.6945967604540665
# Training DSC with lr=0.0001, bs=2000, mdl=1e-05, nr=3
# Optimization started
# Processing epoch	500	0.2259
# Training time: 1167.47s, epochs: 500
#
# Least training loss reached: 0.226
# Accuracy: 0.6625, F1 micro: 0.6625, F1 macro: 0.6601871487813933
# Training DSC with lr=0.0001, bs=2000, mdl=1e-05, nr=5
# Optimization started
# Processing epoch	500	0.2219
# Training time: 1176.20s, epochs: 500
#
# Least training loss reached: 0.222
# Accuracy: 0.6175, F1 micro: 0.6175, F1 macro: 0.6168078591956722
# Training DSC with lr=0.0001, bs=2000, mdl=1e-05, nr=7
# Optimization started
# Processing epoch	500	0.2219
# Training time: 1204.36s, epochs: 500
#
# Least training loss reached: 0.222
# Accuracy: 0.6875, F1 micro: 0.6875, F1 macro: 0.6871695728613347
# Training DSC with lr=0.0001, bs=3000, mdl=1e-07, nr=3
# Optimization started
# Processing epoch	500	0.2206
# Training time: 1182.05s, epochs: 500
#
# Least training loss reached: 0.221
# Accuracy: 0.6575, F1 micro: 0.6575, F1 macro: 0.653863402371162
# Training DSC with lr=0.0001, bs=3000, mdl=1e-07, nr=5
# Optimization started
# Processing epoch	500	0.2236
# Training time: 1183.10s, epochs: 500
#
# Least training loss reached: 0.224
# Accuracy: 0.6375, F1 micro: 0.6375, F1 macro: 0.6364980978822881
# Training DSC with lr=0.0001, bs=3000, mdl=1e-07, nr=7
# Optimization started
# Processing epoch	500	0.2176
# Training time: 1179.42s, epochs: 500
#
# Least training loss reached: 0.218
# Accuracy: 0.675, F1 micro: 0.675, F1 macro: 0.6702516233766234
# Training DSC with lr=0.0001, bs=3000, mdl=1e-06, nr=3
# Optimization started
# Processing epoch	500	0.2272
# Training time: 1176.90s, epochs: 500
#
# Least training loss reached: 0.227
# Accuracy: 0.65, F1 micro: 0.65, F1 macro: 0.6499212322772624
# Training DSC with lr=0.0001, bs=3000, mdl=1e-06, nr=5
# Optimization started
# Processing epoch	500	0.2289
# Training time: 1179.55s, epochs: 500
#
# Least training loss reached: 0.229
# Accuracy: 0.6575, F1 micro: 0.6575, F1 macro: 0.6574807332912476
# Training DSC with lr=0.0001, bs=3000, mdl=1e-06, nr=7
# Optimization started
# Processing epoch	500	0.2211
# Training time: 1180.76s, epochs: 500
#
# Least training loss reached: 0.221
# Accuracy: 0.6675, F1 micro: 0.6675, F1 macro: 0.6670317634173055
# Training DSC with lr=0.0001, bs=3000, mdl=1e-05, nr=3
# Optimization started
# Processing epoch	500	0.2286
# Training time: 1180.52s, epochs: 500
#
# Least training loss reached: 0.229
# Accuracy: 0.665, F1 micro: 0.665, F1 macro: 0.664966496649665
# Training DSC with lr=0.0001, bs=3000, mdl=1e-05, nr=5
# Optimization started
# Processing epoch	500	0.2193
# Training time: 1178.64s, epochs: 500
#
# Least training loss reached: 0.219
# Accuracy: 0.66, F1 micro: 0.66, F1 macro: 0.6593101029584909
# Training DSC with lr=0.0001, bs=3000, mdl=1e-05, nr=7
# Optimization started
# Processing epoch	500	0.2225
# Training time: 1180.18s, epochs: 500
#
# Least training loss reached: 0.223
# Accuracy: 0.6675, F1 micro: 0.6675, F1 macro: 0.66639702516445
# Training DSC with lr=0.0001, bs=4000, mdl=1e-07, nr=3
# Optimization started
# Processing epoch	500	0.2263
# Training time: 1180.57s, epochs: 500
#
# Least training loss reached: 0.226
# Accuracy: 0.6625, F1 micro: 0.6625, F1 macro: 0.6624810145570688
# Training DSC with lr=0.0001, bs=4000, mdl=1e-07, nr=5
# Optimization started
# Processing epoch	500	0.2409
# Training time: 1181.59s, epochs: 500
#
# Least training loss reached: 0.241
# Accuracy: 0.6025, F1 micro: 0.6025, F1 macro: 0.5923886919906942
# Training DSC with lr=0.0001, bs=4000, mdl=1e-07, nr=7
# Optimization started
# Processing epoch	500	0.2203
# Training time: 1180.38s, epochs: 500
#
# Least training loss reached: 0.220
# Accuracy: 0.6775, F1 micro: 0.6775, F1 macro: 0.6703275640657045
# Training DSC with lr=0.0001, bs=4000, mdl=1e-06, nr=3
# Optimization started
# Processing epoch	500	0.2247
# Training time: 1175.56s, epochs: 500
#
# Least training loss reached: 0.225
# Accuracy: 0.64, F1 micro: 0.64, F1 macro: 0.6367214107318551
# Training DSC with lr=0.0001, bs=4000, mdl=1e-06, nr=5
# Optimization started
# Processing epoch	500	0.2185
# Training time: 1180.68s, epochs: 500
#
# Least training loss reached: 0.219
# Accuracy: 0.6675, F1 micro: 0.6675, F1 macro: 0.6674480387560556
# Training DSC with lr=0.0001, bs=4000, mdl=1e-06, nr=7
# Optimization started
# Processing epoch	500	0.2319
# Training time: 1179.65s, epochs: 500
#
# Least training loss reached: 0.232
# Accuracy: 0.6725, F1 micro: 0.6725, F1 macro: 0.6670881009409209
# Training DSC with lr=0.0001, bs=4000, mdl=1e-05, nr=3
# Optimization started
# Processing epoch	500	0.2169
# Training time: 1176.98s, epochs: 500
#
# Least training loss reached: 0.217
# Accuracy: 0.6575, F1 micro: 0.6575, F1 macro: 0.6563638529889446
# Training DSC with lr=0.0001, bs=4000, mdl=1e-05, nr=5
# Optimization started
# Processing epoch	500	0.2146
# Training time: 1177.18s, epochs: 500
#
# Least training loss reached: 0.215
# Accuracy: 0.65, F1 micro: 0.65, F1 macro: 0.6496847162446202
# Training DSC with lr=0.0001, bs=4000, mdl=1e-05, nr=7
# Optimization started
# Processing epoch	500	0.2237
# Training time: 1173.13s, epochs: 500
#
# Least training loss reached: 0.224
# Accuracy: 0.675, F1 micro: 0.675, F1 macro: 0.672346002621232

# %%
df_results = pd.read_csv('results_pos.csv')
df_results = df_results.sort_values(by='accuracy', ascending=False)
df_results.head(5)
# Out:
#         lr    bs           mdl  nr  accuracy  f1_micro  f1_macro
# 5   0.0001  2000  1.000000e-06   7    0.6975    0.6975  0.694597
# 8   0.0001  2000  1.000000e-05   7    0.6875    0.6875  0.687170
# 20  0.0001  4000  1.000000e-07   7    0.6775    0.6775  0.670328
# 26  0.0001  4000  1.000000e-05   7    0.6750    0.6750  0.672346
# 2   0.0001  2000  1.000000e-07   7    0.6750    0.6750  0.671377

# %%
# corremos los 5 mejores modelos y vemos las reglas que generan
dscs = []
for i in range(5):
    lr = df_results.iloc[i]['lr']
    bs = int(df_results.iloc[i]['bs'])
    mdl = df_results.iloc[i]['mdl']
    nr = int(df_results.iloc[i]['nr'])
    DSC = DSClassifierMultiQ(2, min_iter=20, max_iter=500, debug_mode=True, lr=lr, batch_size=bs,
                    lossfn="MSE", num_workers=1, min_dloss=mdl, precompute_rules=True)
    dscs.append(DSC)
    print(f"Training DSC with lr={lr}, bs={bs}, mdl={mdl}, nr={nr}")
    losses, epoch, dt = DSC.fit(X, y, add_single_rules=True,
                single_rules_breaks=nr, add_mult_rules=False,
                    column_names=df.columns[:-1], print_every_epochs=1, print_final_model=False)
    y_pred = DSC.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    f1_micro = f1_score(y_test, y_pred, average='micro')
    f1_macro = f1_score(y_test, y_pred, average='macro')
    print(f"Accuracy: {acc}, F1 micro: {f1_micro}, F1 macro: {f1_macro}")
    print("Rules:")
    DSC.print_most_important_rules(classes=["0",  "1"], threshold=0.19)
# Out:
# Training DSC with lr=0.0001, bs=2000, mdl=1e-06, nr=7
# Optimization started
# Processing epoch	500	0.2222
# Training time: 1167.56s, epochs: 500
#
# Least training loss reached: 0.222
# Accuracy: 0.67, F1 micro: 0.67, F1 macro: 0.6691729323308271
# Rules:
#
#
# Most important rules for class 0
#
# 	[0.233] R54: 0.827 < b8(Y) < 1.022
# 			0: 0.233	1: 0.000	Unc: 0.767
#
# 	[0.224] R73: 0.255 < b3(Y) < 0.438
# 			0: 0.224	1: 0.000	Unc: 0.776
#
# 	[0.218] R52: 0.552 < b8(Y) < 0.682
# 			0: 0.218	1: 0.000	Unc: 0.782
#
# 	[0.211] R0: b2(Y) < 0.599
# 			0: 0.211	1: 0.000	Unc: 0.789
#
# 	[0.201] R51: 0.421 < b8(Y) < 0.552
# 			0: 0.201	1: 0.000	Unc: 0.799
#
# 	[0.196] R63: b4(Y) > 1.061
# 			0: 0.192	1: 0.008	Unc: 0.800
#
# 	[0.195] R19: 0.718 < b6(Y) < 0.824
# 			0: 0.192	1: 0.008	Unc: 0.801
#
# 	[0.193] R99: 0.169 < b13(Y) < 0.299
# 			0: 0.187	1: 0.013	Unc: 0.801
#
# 	[0.192] R98: 0.023 < b13(Y) < 0.169
# 			0: 0.185	1: 0.015	Unc: 0.801
#
# Most important rules for class 1
#
# 	[0.200] R87: b12(Y) > 0.694
# 			0: 0.000	1: 0.200	Unc: 0.800
#
# 	[0.195] R91: 0.192 < b11(Y) < 0.325
# 			0: 0.009	1: 0.190	Unc: 0.801
# Training DSC with lr=0.0001, bs=2000, mdl=1e-05, nr=7
# Optimization started
# Processing epoch	500	0.2254
# Training time: 1126.97s, epochs: 500
#
# Least training loss reached: 0.225
# Accuracy: 0.6675, F1 micro: 0.6675, F1 macro: 0.6532824119031015
# Rules:
#
#
# Most important rules for class 0
#
# 	[0.220] R65: 0.597 < b1(Y) < 0.717
# 			0: 0.220	1: 0.000	Unc: 0.780
#
# 	[0.202] R34: 0.914 < b5(Y) < 0.950
# 			0: 0.202	1: 0.000	Unc: 0.798
#
# 	[0.201] R64: b1(Y) < 0.597
# 			0: 0.201	1: 0.000	Unc: 0.799
#
# 	[0.199] R96: b13(Y) < -0.172
# 			0: 0.199	1: 0.001	Unc: 0.800
#
# 	[0.197] R102: 0.575 < b13(Y) < 0.770
# 			0: 0.195	1: 0.004	Unc: 0.801
#
# 	[0.193] R79: b3(Y) > 1.141
# 			0: 0.187	1: 0.013	Unc: 0.800
#
# Most important rules for class 1
#
# 	[0.246] R21: 0.930 < b6(Y) < 1.048
# 			0: 0.000	1: 0.246	Unc: 0.754
#
# 	[0.204] R84: 0.248 < b12(Y) < 0.371
# 			0: 0.000	1: 0.204	Unc: 0.796
#
# 	[0.197] R101: 0.430 < b13(Y) < 0.575
# 			0: 0.003	1: 0.195	Unc: 0.801
#
# 	[0.195] R37: 1.014 < b5(Y) < 1.050
# 			0: 0.010	1: 0.190	Unc: 0.800
# Training DSC with lr=0.0001, bs=4000, mdl=1e-07, nr=7
# Optimization started
# Processing epoch	500	0.2179
# Training time: 1139.46s, epochs: 500
#
# Least training loss reached: 0.218
# Accuracy: 0.6875, F1 micro: 0.6875, F1 macro: 0.6827391036745156
# Rules:
#
#
# Most important rules for class 0
#
# 	[0.220] R60: 0.993 < b4(Y) < 1.012
# 			0: 0.220	1: 0.000	Unc: 0.780
#
# 	[0.215] R67: 0.806 < b1(Y) < 0.887
# 			0: 0.214	1: 0.001	Unc: 0.785
#
# 	[0.207] R51: 0.421 < b8(Y) < 0.552
# 			0: 0.207	1: 0.000	Unc: 0.793
#
# 	[0.199] R20: 0.824 < b6(Y) < 0.930
# 			0: 0.199	1: 0.000	Unc: 0.801
#
# 	[0.197] R22: 1.048 < b6(Y) < 1.206
# 			0: 0.195	1: 0.005	Unc: 0.800
#
# 	[0.197] R66: 0.717 < b1(Y) < 0.806
# 			0: 0.194	1: 0.005	Unc: 0.801
#
# 	[0.195] R89: -0.155 < b11(Y) < 0.044
# 			0: 0.191	1: 0.008	Unc: 0.801
#
# 	[0.191] R64: b1(Y) < 0.597
# 			0: 0.183	1: 0.016	Unc: 0.801
#
# Most important rules for class 1
#
# 	[0.250] R57: 0.924 < b4(Y) < 0.953
# 			0: 0.000	1: 0.250	Unc: 0.750
#
# 	[0.217] R21: 0.930 < b6(Y) < 1.048
# 			0: 0.000	1: 0.217	Unc: 0.783
#
# 	[0.204] R94: 0.606 < b11(Y) < 0.804
# 			0: 0.000	1: 0.204	Unc: 0.796
#
# 	[0.192] R88: b11(Y) < -0.155
# 			0: 0.015	1: 0.185	Unc: 0.800
# Training DSC with lr=0.0001, bs=4000, mdl=1e-05, nr=7
# Optimization started
# Processing epoch	500	0.2306
# Training time: 1131.54s, epochs: 500
#
# Least training loss reached: 0.231
# Accuracy: 0.62, F1 micro: 0.62, F1 macro: 0.6168968646032866
# Rules:
#
#
# Most important rules for class 0
#
# 	[0.235] R54: 0.827 < b8(Y) < 1.022
# 			0: 0.235	1: 0.000	Unc: 0.765
#
# 	[0.221] R65: 0.597 < b1(Y) < 0.717
# 			0: 0.221	1: 0.000	Unc: 0.779
#
# 	[0.219] R19: 0.718 < b6(Y) < 0.824
# 			0: 0.219	1: 0.000	Unc: 0.781
#
# 	[0.214] R68: 0.887 < b1(Y) < 0.967
# 			0: 0.214	1: 0.000	Unc: 0.786
#
# 	[0.199] R39: b5(Y) > 1.098
# 			0: 0.197	1: 0.003	Unc: 0.800
#
# 	[0.191] R73: 0.255 < b3(Y) < 0.438
# 			0: 0.183	1: 0.016	Unc: 0.801
#
# 	[0.190] R17: 0.441 < b6(Y) < 0.600
# 			0: 0.182	1: 0.017	Unc: 0.801
#
# Most important rules for class 1
#
# 	[0.203] R69: 0.967 < b1(Y) < 1.056
# 			0: 0.000	1: 0.203	Unc: 0.797
#
# 	[0.196] R94: 0.606 < b11(Y) < 0.804
# 			0: 0.005	1: 0.194	Unc: 0.801
#
# 	[0.195] R14: 1.009 < b7(Y) < 1.113
# 			0: 0.010	1: 0.190	Unc: 0.800
#
# 	[0.194] R63: b4(Y) > 1.061
# 			0: 0.012	1: 0.188	Unc: 0.800
#
# 	[0.191] R37: 1.014 < b5(Y) < 1.050
# 			0: 0.018	1: 0.182	Unc: 0.800
# Training DSC with lr=0.0001, bs=2000, mdl=1e-07, nr=7
# Optimization started
# Processing epoch	500	0.2244
# Training time: 1130.60s, epochs: 500
#
# Least training loss reached: 0.224
# Accuracy: 0.6425, F1 micro: 0.6425, F1 macro: 0.642479889493784
# Rules:
#
#
# Most important rules for class 0
#
# 	[0.243] R99: 0.169 < b13(Y) < 0.299
# 			0: 0.243	1: 0.000	Unc: 0.757
#
# 	[0.242] R98: 0.023 < b13(Y) < 0.169
# 			0: 0.242	1: 0.000	Unc: 0.758
#
# 	[0.230] R58: 0.953 < b4(Y) < 0.974
# 			0: 0.230	1: 0.000	Unc: 0.770
#
# 	[0.206] R66: 0.717 < b1(Y) < 0.806
# 			0: 0.206	1: 0.000	Unc: 0.794
#
# 	[0.200] R12: 0.862 < b7(Y) < 0.932
# 			0: 0.200	1: 0.000	Unc: 0.800
#
# 	[0.198] R39: b5(Y) > 1.098
# 			0: 0.197	1: 0.003	Unc: 0.800
#
# 	[0.196] R102: 0.575 < b13(Y) < 0.770
# 			0: 0.194	1: 0.005	Unc: 0.801
#
# 	[0.194] R82: -0.014 < b12(Y) < 0.124
# 			0: 0.191	1: 0.007	Unc: 0.802
#
# 	[0.192] R8: b7(Y) < 0.611
# 			0: 0.186	1: 0.013	Unc: 0.801
#
# Most important rules for class 1
#
# 	[0.226] R91: 0.192 < b11(Y) < 0.325
# 			0: 0.000	1: 0.226	Unc: 0.774
#
# 	[0.213] R26: 0.393 < b9(Y) < 0.539
# 			0: 0.000	1: 0.213	Unc: 0.787
#
# 	[0.198] R1: 0.599 < b2(Y) < 0.721
# 			0: 0.000	1: 0.198	Unc: 0.802

# %%
#random forest
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100, max_depth=4, random_state=0)
rf.fit(X, y)
y_pred = rf.predict(X_test)
acc = accuracy_score(y_test, y_pred)
f1_micro = f1_score(y_test, y_pred, average='micro')
f1_macro = f1_score(y_test, y_pred, average='macro')
print(f"Accuracy: {acc}, F1 micro: {f1_micro}, F1 macro: {f1_macro}")
# Out:
# Accuracy: 0.67, F1 micro: 0.67, F1 macro: 0.6669946265042004
