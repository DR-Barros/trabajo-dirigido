# %%
import pandas as pd
import numpy as np

from dsgd.DSClassifierMultiQ import DSClassifierMultiQ

from sklearn.metrics import accuracy_score, confusion_matrix, f1_score

# %%
df = pd.read_csv("https://huggingface.co/datasets/furrutiav/sac_nllf/raw/main/train.csv")
df = df.drop(columns=['index', "b1(Y)", "b2(Y)", "b3(Y)", "b4(Y)", "b5(Y)", "b6(Y)", "b7(Y)", "b8(Y)", "b9(Y)", "b10(Y)", "b11(Y)", "b12(Y)", "b13(Y)"])
print("Dataframe shape: ", df.shape)
df.head()
test = pd.read_csv("https://huggingface.co/datasets/furrutiav/sac_nllf/raw/main/test.csv")
test = test.drop(columns=['index', "b1(Y)", "b2(Y)", "b3(Y)", "b4(Y)", "b5(Y)", "b6(Y)", "b7(Y)", "b8(Y)", "b9(Y)", "b10(Y)", "b11(Y)", "b12(Y)", "b13(Y)"])
print("Dataframe shape: ", test.shape)
# Out:
# Dataframe shape:  (1400, 14)
# Dataframe shape:  (400, 14)

# %%
y = df['label']
X = df.drop(columns=['label'])
y = y.to_numpy()
X = X.to_numpy()    
y_test = test['label']
X_test = test.drop(columns=['label'])
X_test = X_test.to_numpy()
y_test = y_test.to_numpy()

# %%
DSCs = {}
time = {}
accuracys = {}
learning_rates = [0.0001, ]
batch_sizes = [2000, 3000, 4000]
min_dl = [1e-7, 1e-6, 1e-5,]
num_rules = [3, 5, 7,]
df_results = pd.DataFrame(columns=['lr', 'bs', 'mdl', 'nr', 'accuracy', 'f1_micro', 'f1_macro'])
results = []
for lr in learning_rates:
    for bs in batch_sizes:
        for mdl in min_dl:
            for nr in num_rules:
                DSC = DSClassifierMultiQ(2, min_iter=20, max_iter=500, debug_mode=True, lr=lr, batch_size=bs,
                                lossfn="MSE", num_workers=1, min_dloss=mdl, precompute_rules=True)
                print(f"Training DSC with lr={lr}, bs={bs}, mdl={mdl}, nr={nr}")
                losses, epoch, dt = DSC.fit(X, y, add_single_rules=True,
                            single_rules_breaks=nr, add_mult_rules=False,
                                column_names=df.columns[:-1], print_every_epochs=1, print_final_model=False)
                y_pred = DSC.predict(X_test)
                acc = accuracy_score(y_test, y_pred)
                f1_micro = f1_score(y_test, y_pred, average='micro')
                f1_macro = f1_score(y_test, y_pred, average='macro')
                print(f"Accuracy: {acc}, F1 micro: {f1_micro}, F1 macro: {f1_macro}")
                new_row = pd.DataFrame({
                    'lr': [lr], 'bs': [bs], 'mdl': [mdl], 'nr': [nr],
                    'accuracy': [acc], 'f1_micro': [f1_micro], 'f1_macro': [f1_macro]
                })
                df_results = pd.concat([df_results, new_row])
                results.append({
                    'lr': lr, 'bs': bs, 'mdl': mdl, 'nr': nr,
                    'accuracy': acc, 'f1_micro': f1_micro, 'f1_macro': f1_macro
                })
                

df_results.to_csv("results_neg.csv", index=False)
# Out:
# Training DSC with lr=0.0001, bs=2000, mdl=1e-07, nr=3
# Optimization started
# Processing epoch	500	0.2230
# Training time: 1207.46s, epochs: 500
#
# Least training loss reached: 0.223
# Accuracy: 0.6725, F1 micro: 0.6725, F1 macro: 0.6714136112522027
# Training DSC with lr=0.0001, bs=2000, mdl=1e-07, nr=5
# Optimization started
# Processing epoch	1	1.0000
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_16312\3816186185.py:29: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_results = pd.concat([df_results, new_row])
# Processing epoch	500	0.2176
# Training time: 1169.19s, epochs: 500
#
# Least training loss reached: 0.218
# Accuracy: 0.66, F1 micro: 0.66, F1 macro: 0.6598639455782312
# Training DSC with lr=0.0001, bs=2000, mdl=1e-07, nr=7
# Optimization started
# Processing epoch	500	0.2273
# Training time: 1196.09s, epochs: 500
#
# Least training loss reached: 0.227
# Accuracy: 0.6275, F1 micro: 0.6275, F1 macro: 0.6255317010033992
# Training DSC with lr=0.0001, bs=2000, mdl=1e-06, nr=3
# Optimization started
# Processing epoch	500	0.2206
# Training time: 1192.99s, epochs: 500
#
# Least training loss reached: 0.221
# Accuracy: 0.665, F1 micro: 0.665, F1 macro: 0.6622643411634237
# Training DSC with lr=0.0001, bs=2000, mdl=1e-06, nr=5
# Optimization started
# Processing epoch	500	0.2323
# Training time: 1202.33s, epochs: 500
#
# Least training loss reached: 0.232
# Accuracy: 0.6425, F1 micro: 0.6425, F1 macro: 0.6383203394224507
# Training DSC with lr=0.0001, bs=2000, mdl=1e-06, nr=7
# Optimization started
# Processing epoch	500	0.2308
# Training time: 1170.08s, epochs: 500
#
# Least training loss reached: 0.231
# Accuracy: 0.655, F1 micro: 0.655, F1 macro: 0.6527777777777778
# Training DSC with lr=0.0001, bs=2000, mdl=1e-05, nr=3
# Optimization started
# Processing epoch	500	0.2257
# Training time: 1163.02s, epochs: 500
#
# Least training loss reached: 0.226
# Accuracy: 0.6525, F1 micro: 0.6525, F1 macro: 0.6498189261533617
# Training DSC with lr=0.0001, bs=2000, mdl=1e-05, nr=5
# Optimization started
# Processing epoch	500	0.2274
# Training time: 1170.37s, epochs: 500
#
# Least training loss reached: 0.227
# Accuracy: 0.6275, F1 micro: 0.6275, F1 macro: 0.6268259543800991
# Training DSC with lr=0.0001, bs=2000, mdl=1e-05, nr=7
# Optimization started
# Processing epoch	500	0.2157
# Training time: 1198.54s, epochs: 500
#
# Least training loss reached: 0.216
# Accuracy: 0.66, F1 micro: 0.66, F1 macro: 0.6587715776796468
# Training DSC with lr=0.0001, bs=3000, mdl=1e-07, nr=3
# Optimization started
# Processing epoch	500	0.2316
# Training time: 1174.71s, epochs: 500
#
# Least training loss reached: 0.232
# Accuracy: 0.6325, F1 micro: 0.6325, F1 macro: 0.6323138588910635
# Training DSC with lr=0.0001, bs=3000, mdl=1e-07, nr=5
# Optimization started
# Processing epoch	500	0.2235
# Training time: 1174.85s, epochs: 500
#
# Least training loss reached: 0.223
# Accuracy: 0.64, F1 micro: 0.64, F1 macro: 0.63996399639964
# Training DSC with lr=0.0001, bs=3000, mdl=1e-07, nr=7
# Optimization started
# Processing epoch	500	0.2221
# Training time: 1173.57s, epochs: 500
#
# Least training loss reached: 0.222
# Accuracy: 0.645, F1 micro: 0.645, F1 macro: 0.6449911247781195
# Training DSC with lr=0.0001, bs=3000, mdl=1e-06, nr=3
# Optimization started
# Processing epoch	500	0.2387
# Training time: 1169.46s, epochs: 500
#
# Least training loss reached: 0.239
# Accuracy: 0.62, F1 micro: 0.62, F1 macro: 0.6015831826164452
# Training DSC with lr=0.0001, bs=3000, mdl=1e-06, nr=5
# Optimization started
# Processing epoch	500	0.2205
# Training time: 1172.12s, epochs: 500
#
# Least training loss reached: 0.220
# Accuracy: 0.6475, F1 micro: 0.6475, F1 macro: 0.6473920138042275
# Training DSC with lr=0.0001, bs=3000, mdl=1e-06, nr=7
# Optimization started
# Processing epoch	500	0.2212
# Training time: 1173.68s, epochs: 500
#
# Least training loss reached: 0.221
# Accuracy: 0.675, F1 micro: 0.675, F1 macro: 0.6664614121510674
# Training DSC with lr=0.0001, bs=3000, mdl=1e-05, nr=3
# Optimization started
# Processing epoch	500	0.2196
# Training time: 1172.94s, epochs: 500
#
# Least training loss reached: 0.220
# Accuracy: 0.63, F1 micro: 0.63, F1 macro: 0.6250411694661904
# Training DSC with lr=0.0001, bs=3000, mdl=1e-05, nr=5
# Optimization started
# Processing epoch	500	0.2302
# Training time: 1176.60s, epochs: 500
#
# Least training loss reached: 0.230
# Accuracy: 0.635, F1 micro: 0.635, F1 macro: 0.6349634963496349
# Training DSC with lr=0.0001, bs=3000, mdl=1e-05, nr=7
# Optimization started
# Processing epoch	500	0.2255
# Training time: 1179.84s, epochs: 500
#
# Least training loss reached: 0.225
# Accuracy: 0.6575, F1 micro: 0.6575, F1 macro: 0.6531096692514637
# Training DSC with lr=0.0001, bs=4000, mdl=1e-07, nr=3
# Optimization started
# Processing epoch	500	0.2347
# Training time: 1171.04s, epochs: 500
#
# Least training loss reached: 0.235
# Accuracy: 0.6325, F1 micro: 0.6325, F1 macro: 0.6312809225501816
# Training DSC with lr=0.0001, bs=4000, mdl=1e-07, nr=5
# Optimization started
# Processing epoch	500	0.2232
# Training time: 1175.06s, epochs: 500
#
# Least training loss reached: 0.223
# Accuracy: 0.6525, F1 micro: 0.6525, F1 macro: 0.6524804520254264
# Training DSC with lr=0.0001, bs=4000, mdl=1e-07, nr=7
# Optimization started
# Processing epoch	500	0.2189
# Training time: 1173.61s, epochs: 500
#
# Least training loss reached: 0.219
# Accuracy: 0.6425, F1 micro: 0.6425, F1 macro: 0.6413140947256868
# Training DSC with lr=0.0001, bs=4000, mdl=1e-06, nr=3
# Optimization started
# Processing epoch	500	0.2242
# Training time: 1171.04s, epochs: 500
#
# Least training loss reached: 0.224
# Accuracy: 0.6475, F1 micro: 0.6475, F1 macro: 0.6473920138042275
# Training DSC with lr=0.0001, bs=4000, mdl=1e-06, nr=5
# Optimization started
# Processing epoch	500	0.2344
# Training time: 1176.91s, epochs: 500
#
# Least training loss reached: 0.234
# Accuracy: 0.63, F1 micro: 0.63, F1 macro: 0.6299907497687443
# Training DSC with lr=0.0001, bs=4000, mdl=1e-06, nr=7
# Optimization started
# Processing epoch	500	0.2191
# Training time: 1175.45s, epochs: 500
#
# Least training loss reached: 0.219
# Accuracy: 0.67, F1 micro: 0.67, F1 macro: 0.6699917497937449
# Training DSC with lr=0.0001, bs=4000, mdl=1e-05, nr=3
# Optimization started
# Processing epoch	500	0.2284
# Training time: 1174.53s, epochs: 500
#
# Least training loss reached: 0.228
# Accuracy: 0.6425, F1 micro: 0.6425, F1 macro: 0.6308701011235229
# Training DSC with lr=0.0001, bs=4000, mdl=1e-05, nr=5
# Optimization started
# Processing epoch	500	0.2244
# Training time: 1173.24s, epochs: 500
#
# Least training loss reached: 0.224
# Accuracy: 0.6725, F1 micro: 0.6725, F1 macro: 0.6679151535892415
# Training DSC with lr=0.0001, bs=4000, mdl=1e-05, nr=7
# Optimization started
# Processing epoch	500	0.2337
# Training time: 1171.94s, epochs: 500
#
# Least training loss reached: 0.234
# Accuracy: 0.635, F1 micro: 0.635, F1 macro: 0.635

# %%
df_results = pd.read_csv('results_neg.csv')
df_results = df_results.sort_values(by='accuracy', ascending=False)
df_results.head(5)
# Out:
#         lr    bs           mdl  nr  accuracy  f1_micro  f1_macro
# 14  0.0001  3000  1.000000e-06   7    0.6750    0.6750  0.666461
# 0   0.0001  2000  1.000000e-07   3    0.6725    0.6725  0.671414
# 25  0.0001  4000  1.000000e-05   5    0.6725    0.6725  0.667915
# 23  0.0001  4000  1.000000e-06   7    0.6700    0.6700  0.669992
# 3   0.0001  2000  1.000000e-06   3    0.6650    0.6650  0.662264

# %%
# corremos los 5 mejores modelos y vemos las reglas que generan
dscs = []
for i in range(5):
    lr = df_results.iloc[i]['lr']
    bs = int(df_results.iloc[i]['bs'])
    mdl = df_results.iloc[i]['mdl']
    nr = int(df_results.iloc[i]['nr'])
    DSC = DSClassifierMultiQ(2, min_iter=20, max_iter=500, debug_mode=True, lr=lr, batch_size=bs,
                    lossfn="MSE", num_workers=1, min_dloss=mdl, precompute_rules=True)
    dscs.append(DSC)
    print(f"Training DSC with lr={lr}, bs={bs}, mdl={mdl}, nr={nr}")
    losses, epoch, dt = DSC.fit(X, y, add_single_rules=True,
                single_rules_breaks=nr, add_mult_rules=False,
                    column_names=df.columns[:-1], print_every_epochs=1, print_final_model=False)
    y_pred = DSC.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    f1_micro = f1_score(y_test, y_pred, average='micro')
    f1_macro = f1_score(y_test, y_pred, average='macro')
    print(f"Accuracy: {acc}, F1 micro: {f1_micro}, F1 macro: {f1_macro}")
    print("Rules:")
    DSC.print_most_important_rules(classes=["0",  "1"], threshold=0.19)
# Out:
# Training DSC with lr=0.0001, bs=3000, mdl=1e-06, nr=7
# Optimization started
# Processing epoch	500	0.2262
# Training time: 1161.77s, epochs: 500
#
# Least training loss reached: 0.226
# Accuracy: 0.655, F1 micro: 0.655, F1 macro: 0.6465073388150311
# Rules:
#
#
# Most important rules for class 0
#
# 	[0.243] R38: 0.084 < b5(N) < 0.130
# 			0: 0.243	1: 0.000	Unc: 0.757
#
# 	[0.239] R69: 0.193 < b1(N) < 0.282
# 			0: 0.239	1: 0.000	Unc: 0.761
#
# 	[0.235] R22: 0.435 < b6(N) < 0.600
# 			0: 0.235	1: 0.000	Unc: 0.765
#
# 	[0.234] R7: b2(N) > 0.380
# 			0: 0.234	1: 0.000	Unc: 0.766
#
# 	[0.215] R4: 0.096 < b2(N) < 0.175
# 			0: 0.215	1: 0.000	Unc: 0.785
#
# 	[0.203] R35: -0.013 < b5(N) < 0.018
# 			0: 0.203	1: 0.000	Unc: 0.797
#
# 	[0.195] R8: b7(N) < -0.110
# 			0: 0.190	1: 0.010	Unc: 0.800
#
# 	[0.193] R65: -0.172 < b1(N) < -0.053
# 			0: 0.187	1: 0.013	Unc: 0.800
#
# 	[0.193] R57: -0.059 < b4(N) < -0.031
# 			0: 0.187	1: 0.013	Unc: 0.800
#
# 	[0.193] R13: 0.163 < b7(N) < 0.229
# 			0: 0.188	1: 0.011	Unc: 0.801
#
# 	[0.193] R70: 0.282 < b1(N) < 0.400
# 			0: 0.188	1: 0.011	Unc: 0.801
#
# 	[0.193] R25: -0.147 < b9(N) < 0.041
# 			0: 0.187	1: 0.012	Unc: 0.801
#
# 	[0.193] R37: 0.049 < b5(N) < 0.084
# 			0: 0.187	1: 0.012	Unc: 0.801
#
# Most important rules for class 1
#
# 	[0.223] R91: 0.558 < b11(N) < 0.689
# 			0: 0.000	1: 0.223	Unc: 0.777
#
# 	[0.203] R54: 0.688 < b8(N) < 0.880
# 			0: 0.000	1: 0.203	Unc: 0.797
#
# 	[0.196] R84: 0.766 < b12(N) < 0.886
# 			0: 0.006	1: 0.193	Unc: 0.801
#
# 	[0.194] R0: b2(N) < -0.187
# 			0: 0.011	1: 0.189	Unc: 0.800
#
# 	[0.194] R83: 0.647 < b12(N) < 0.766
# 			0: 0.010	1: 0.189	Unc: 0.801
#
# 	[0.192] R66: -0.053 < b1(N) < 0.035
# 			0: 0.014	1: 0.185	Unc: 0.801
# Training DSC with lr=0.0001, bs=2000, mdl=1e-07, nr=3
# Optimization started
# Processing epoch	500	0.2210
# Training time: 1125.68s, epochs: 500
#
# Least training loss reached: 0.221
# Accuracy: 0.6625, F1 micro: 0.6625, F1 macro: 0.6620247222656861
# Rules:
#
#
# Most important rules for class 0
#
# 	[0.239] R47: b11(N) > 0.965
# 			0: 0.239	1: 0.000	Unc: 0.761
#
# Most important rules for class 1
#
# 	[0.227] R33: -0.053 < b1(N) < 0.114
# 			0: 0.000	1: 0.227	Unc: 0.773
#
# 	[0.197] R44: b11(N) < 0.413
# 			0: 0.003	1: 0.196	Unc: 0.801
# Training DSC with lr=0.0001, bs=4000, mdl=1e-05, nr=5
# Optimization started
# Processing epoch	500	0.2213
# Training time: 1139.31s, epochs: 500
#
# Least training loss reached: 0.221
# Accuracy: 0.6625, F1 micro: 0.6625, F1 macro: 0.6624810145570688
# Rules:
#
#
# Most important rules for class 0
#
# 	[0.223] R37: 0.029 < b8(N) < 0.244
# 			0: 0.223	1: 0.000	Unc: 0.777
#
# 	[0.216] R28: 0.060 < b5(N) < 0.112
# 			0: 0.216	1: 0.000	Unc: 0.784
#
# 	[0.213] R51: 0.114 < b1(N) < 0.221
# 			0: 0.213	1: 0.000	Unc: 0.787
#
# 	[0.211] R70: 0.865 < b11(N) < 1.084
# 			0: 0.211	1: 0.000	Unc: 0.789
#
# 	[0.206] R16: 0.350 < b6(N) < 0.536
# 			0: 0.206	1: 0.000	Unc: 0.794
#
# 	[0.195] R0: b2(N) < -0.142
# 			0: 0.191	1: 0.009	Unc: 0.800
#
# 	[0.194] R53: b1(N) > 0.355
# 			0: 0.190	1: 0.009	Unc: 0.801
#
# Most important rules for class 1
#
# 	[0.231] R63: 0.766 < b12(N) < 0.928
# 			0: 0.000	1: 0.231	Unc: 0.769
#
# 	[0.222] R60: b12(N) < 0.403
# 			0: 0.000	1: 0.222	Unc: 0.778
#
# 	[0.201] R67: 0.293 < b11(N) < 0.513
# 			0: 0.000	1: 0.201	Unc: 0.799
#
# 	[0.195] R22: 0.477 < b9(N) < 0.689
# 			0: 0.009	1: 0.190	Unc: 0.801
# Training DSC with lr=0.0001, bs=4000, mdl=1e-06, nr=7
# Optimization started
# Processing epoch	500	0.2203
# Training time: 1130.44s, epochs: 500
#
# Least training loss reached: 0.220
# Accuracy: 0.665, F1 micro: 0.665, F1 macro: 0.6605102480301994
# Rules:
#
#
# Most important rules for class 0
#
# 	[0.220] R41: -0.139 < b10(N) < 0.032
# 			0: 0.220	1: 0.000	Unc: 0.780
#
# 	[0.207] R67: 0.035 < b1(N) < 0.114
# 			0: 0.207	1: 0.000	Unc: 0.793
#
# 	[0.203] R7: b2(N) > 0.380
# 			0: 0.203	1: 0.000	Unc: 0.797
#
# 	[0.193] R95: b11(N) > 1.159
# 			0: 0.186	1: 0.014	Unc: 0.800
#
# 	[0.192] R3: 0.018 < b2(N) < 0.096
# 			0: 0.184	1: 0.015	Unc: 0.801
#
# 	[0.190] R38: 0.084 < b5(N) < 0.130
# 			0: 0.182	1: 0.017	Unc: 0.801
#
# 	[0.190] R12: 0.104 < b7(N) < 0.163
# 			0: 0.182	1: 0.016	Unc: 0.802
#
# Most important rules for class 1
#
# 	[0.214] R18: -0.033 < b6(N) < 0.090
# 			0: 0.000	1: 0.214	Unc: 0.786
#
# 	[0.201] R91: 0.558 < b11(N) < 0.689
# 			0: 0.000	1: 0.201	Unc: 0.799
#
# 	[0.199] R81: 0.335 < b12(N) < 0.513
# 			0: 0.001	1: 0.198	Unc: 0.801
#
# 	[0.190] R1: -0.187 < b2(N) < -0.070
# 			0: 0.019	1: 0.181	Unc: 0.800
# Training DSC with lr=0.0001, bs=2000, mdl=1e-06, nr=3
# Optimization started
# Processing epoch	500	0.2322
# Training time: 1130.54s, epochs: 500
#
# Least training loss reached: 0.232
# Accuracy: 0.6125, F1 micro: 0.6125, F1 macro: 0.6124394436630723
# Rules:
#
#
# Most important rules for class 0
#
# 	[0.209] R39: b3(N) > 0.542
# 			0: 0.209	1: 0.000	Unc: 0.791
#
# 	[0.197] R3: b2(N) > 0.262
# 			0: 0.197	1: 0.002	Unc: 0.802
#
# 	[0.197] R50: 0.679 < b13(N) < 0.959
# 			0: 0.195	1: 0.003	Unc: 0.802
#
# 	[0.196] R18: 0.018 < b5(N) < 0.084
# 			0: 0.193	1: 0.005	Unc: 0.802
#
# 	[0.192] R11: b6(N) > 0.435
# 			0: 0.186	1: 0.012	Unc: 0.801
#
# Most important rules for class 1
#
# 	[0.209] R51: b13(N) > 0.959
# 			0: 0.000	1: 0.209	Unc: 0.791
#
# 	[0.191] R46: 0.689 < b11(N) < 0.965
# 			0: 0.017	1: 0.183	Unc: 0.800

# %%
#random forest
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100, max_depth=4, random_state=0)
rf.fit(X, y)
y_pred = rf.predict(X_test)
acc = accuracy_score(y_test, y_pred)
f1_micro = f1_score(y_test, y_pred, average='micro')
f1_macro = f1_score(y_test, y_pred, average='macro')
print(f"Accuracy: {acc}, F1 micro: {f1_micro}, F1 macro: {f1_macro}")
# Out:
# Accuracy: 0.68, F1 micro: 0.68, F1 macro: 0.6767676767676768
